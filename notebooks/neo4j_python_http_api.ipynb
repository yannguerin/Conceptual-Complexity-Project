# %%
import requests
import time
import base64
import json

# %%
# Authentication
from settings import URI, AUTH

username, password = AUTH
credentials = f"{username}:{password}"

# Base64 encode the credentials
credentials_b64 = base64.b64encode(credentials.encode()).decode()

# Define the Authorization header
headers = {
  "Authorization": f"Basic {credentials_b64}"
}

# %%
# Define the Neo4j endpoint
endpoint = "http://localhost:7474/db/data/transaction/commit"

session = requests.Session()

def get_word_rows(json_response):
    return  [(data['row'][0][-3]['value'], data['row'][0][-1]['value']) for data in json_response["results"][0]['data']]

def get_word_paths(session, value, path_length):
    # Define the Neo4j query
    query = {
      "statements": [
        {
          "statement": f"MATCH (w:Word) USING TEXT INDEX w:Word(value) WHERE w.value = '{value}' MATCH p = (w)-[:HAS_WORD*1..{path_length}]->(:Word) WITH collect(distinct nodes(p)) AS uniqueNode UNWIND uniqueNode AS n RETURN n;",
          "resultDataContents": ["row"]
        }
      ]
    }

    # Send the request to the Neo4j endpoint
    request_time = time.time()
    response = session.post(endpoint, json=query, headers=headers)
    print(time.time() - request_time)
    # Print the response
    return response.json()

def get_word_data(session, value, path_length):
    json_response_time = time.time()
    word_path = get_word_paths(session, value, path_length)
    print(time.time() - json_response_time)
    return get_word_rows(word_path)

# %%
path = get_word_paths(session, "defenestration", 3)
# Out:
# 0.4757564067840576

# %%
path["errors"]
# Out:
# []

# %%
len(path["results"][0]["data"])
# Out:
# 41586

# %%
# Call the function with the parameters
start = time.time()
word_path = get_word_data(session, "defenestration", 2)
print(time.time() - start)
# Out:
# 2.104249954223633
# 2.104249954223633
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[224], line 3
#       1 # Call the function with the parameters
#       2 start = time.time()
# ----> 3 word_path = get_word_data(session, "defenestration", 2)
#       4 print(time.time() - start)
#
# Cell In[223], line 31, in get_word_data(session, value, path_length)
#      29 word_path = get_word_paths(session, value, path_length)
#      30 print(time.time() - json_response_time)
# ---> 31 return get_word_rows(word_path)
#
# Cell In[223], line 7, in get_word_rows(json_response)
#       6 def get_word_rows(json_response):
# ----> 7     return  [(data['row'][0][-3]['value'], data['row'][0][-1]['value']) for data in json_response["results"][0]['data']]
#
# IndexError: list index out of range

# %%
word_path
# Out:
# [('defenestration', 'thing'),
#  ('thing', 'fashionable'),
#  ('thing', 'mild'),
#  ('thing', 'dressing'),
#  ('thing', 'possession'),
#  ('thing', 'act'),
#  ('thing', 'something'),
#  ('thing', 'product'),
#  ('thing', 'usually'),
#  ('thing', 'material'),
#  ('thing', 'observation'),
#  ('thing', 'imply'),
#  ('thing', 'not'),
#  ('thing', 'being'),
#  ('thing', 'living'),
#  ('thing', 'talk'),
#  ('thing', 'appeal'),
#  ('thing', 'precisely'),
#  ('thing', 'situation'),
#  ('thing', 'proper'),
#  ('thing', 'separate'),
#  ('thing', 'specialty'),
#  ('thing', 'general'),
#  ('thing', 'from'),
#  ('thing', 'article'),
#  ('thing', 'to'),
#  ('thing', 'write'),
#  ('thing', 'designate'),
#  ('thing', 'accomplishment'),
#  ('thing', 'activity'),
#  ('thing', 'of'),
#  ('thing', 'an'),
#  ('thing', 'distinguished'),
#  ('thing', 'concern'),
#  ('thing', 'news'),
#  ('thing', 'appearance'),
#  ('thing', 'spatial'),
#  ('thing', 'obsession'),
#  ('thing', 'the'),
#  ('thing', 'make'),
#  ('thing', 'entity'),
#  ('thing', 'own'),
#  ('thing', 'concrete'),
#  ('thing', 'circumstance'),
#  ('thing', 'utensil'),
#  ('thing', 'clothing'),
#  ('thing', 'spoken'),
#  ('thing', 'as'),
#  ('thing', 'detail'),
#  ('thing', 'effort'),
#  ('thing', 'a'),
#  ('thing', 'way'),
#  ('thing', 'equipment'),
#  ('thing', 'notion'),
#  ('thing', 'particular'),
#  ('thing', 'sphere'),
#  ('thing', 'inanimate'),
#  ('thing', 'state'),
#  ('thing', 'forte'),
#  ('thing', 'kind'),
#  ('thing', 'and'),
#  ('thing', 'purpose'),
#  ('thing', 'behave'),
#  ('thing', 'event'),
#  ('thing', 'object'),
#  ('thing', 'individual'),
#  ('thing', 'strong'),
#  ('thing', 'its'),
#  ('thing', 'matter'),
#  ('thing', 'within'),
#  ('thing', 'in'),
#  ('thing', 'point'),
#  ('thing', 'for'),
#  ('thing', 'or'),
#  ('thing', 'work'),
#  ('thing', 'substance'),
#  ('thing', 'aim'),
#  ('thing', 'distinct'),
#  ('thing', 'information'),
#  ('thing', 'phobia'),
#  ('thing', 'specify'),
#  ('thing', 'quality'),
#  ('thing', 'possessed'),
#  ('thing', 'piece'),
#  ('thing', 'especially'),
#  ('thing', 'capable'),
#  ('thing', 'such'),
#  ('thing', 'that'),
#  ('thing', 'fact'),
#  ('thing', 'right'),
#  ('thing', 'effect'),
#  ('thing', 'idea'),
#  ('thing', 'deed'),
#  ('thing', 'whatever'),
#  ('thing', 'be'),
#  ('thing', 'may'),
#  ('thing', 'affair'),
#  ('defenestration', 'office'),
#  ('office', 'office'),
#  ('office', 'building'),
#  ('office', 'emolument'),
#  ('office', 'special'),
#  ('office', 'charge'),
#  ('office', 'duty'),
#  ('office', 'to'),
#  ('office', 'executive'),
#  ('office', 'where'),
#  ('office', 'outhouse'),
#  ('office', 'in'),
#  ('office', 'direct'),
#  ('office', 'may'),
#  ('office', 'by'),
#  ('office', 'divine'),
#  ('office', 'degree'),
#  ('office', 'receive'),
#  ('office', 'place'),
#  ('office', 'responsibility'),
#  ('office', 'activity'),
#  ('office', 'task'),
#  ('office', 'prescribe'),
#  ('office', 'for'),
#  ('office', 'are'),
#  ('office', 'form'),
#  ('office', 'assumed'),
#  ('office', 'administrative'),
#  ('office', 'done'),
#  ('office', 'house'),
#  ('office', 'the'),
#  ('office', 'supply'),
#  ('office', 'ceremonial'),
#  ('office', 'some'),
#  ('office', 'purpose'),
#  ('office', 'role'),
#  ('office', 'unit'),
#  ('office', 'governmental'),
#  ('office', 'officer'),
#  ('office', 'observance'),
#  ('office', 'religious'),
#  ('office', 'that'),
#  ('office', 'service'),
#  ('office', 'something'),
#  ('office', 'organization'),
#  ('office', 'business'),
#  ('office', 'ought'),
#  ('office', 'proper'),
#  ('office', 'department'),
#  ('office', 'assign'),
#  ('office', 'perform'),
#  ('office', 'one'),
#  ('office', 'rite'),
#  ('office', 'an'),
#  ('office', 'major'),
#  ('office', 'as'),
#  ('office', 'position'),
#  ('office', 'enterprise'),
#  ('office', 'kind'),
#  ('office', 'confer'),
#  ('office', 'professional'),
#  ('office', 'such'),
#  ('office', 'or'),
#  ('office', 'function'),
#  ('office', 'conduct'),
#  ('office', 'a'),
#  ('office', 'subdivision'),
#  ('office', 'carry'),
#  ('office', 'another'),
#  ('office', 'exercise'),
#  ('office', 'apartment'),
#  ('office', 'action'),
#  ('office', 'is'),
#  ('office', 'worship'),
#  ('office', 'on'),
#  ('office', 'which'),
#  ('office', 'government'),
#  ('office', 'of'),
#  ('office', 'do'),
#  ('office', 'belong'),
#  ('office', 'attached'),
#  ('office', 'public'),
#  ('office', 'authority'),
#  ('office', 'whatever'),
#  ('office', 'it'),
#  ('office', 'and'),
#  ('office', 'transact'),
#  ('office', 'customary'),
#  ('office', 'person'),
#  ('office', 'headquarters'),
#  ('office', 'particular'),
#  ('office', 'must'),
#  ('office', 'social'),
#  ('defenestration', 'usually'),
#  ('usually', 'p'),
#  ('usually', 'not'),
#  ('usually', 'things'),
#  ('usually', 'them'),
#  ('usually', 'die'),
#  ('usually', 'away'),
#  ('usually', 'a'),
#  ('usually', 'it'),
#  ('usually', 'does'),
#  ('usually', 'back'),
#  ('usually', 'predator'),
#  ('usually', 'rule'),
#  ('usually', 'whether'),
#  ('usually', 'ordinarily'),
#  ('usually', 'often'),
#  ('usually', 'customarily'),
#  ('usually', 'go'),
#  ('usually', 'as'),
#  ('usually', 'care'),
#  ('usually', 'the'),
#  ('usually', 'most'),
#  ('usually', 'accord'),
#  ('usually', 'plant'),
#  ('usually', 'course'),
#  ('usually', 'and'),
#  ('usually', 'mattson'),
#  ('usually', 'or'),
#  ('usually', 'to'),
#  ('usually', 'just'),
#  ('usually', 'want'),
#  ('usually', 'usual'),
#  ('usually', 'come'),
#  ('usually', 'ordinary'),
#  ('usually', 'of'),
#  ('defenestration', 'political'),
#  ('political', 'political'),
#  ('political', 'government'),
#  ('political', 'a'),
#  ('political', 'or'),
#  ('political', 'policy'),
#  ('political', 'concerned'),
#  ('political', 'the'),
#  ('political', 'organized'),
#  ('political', 'against'),
#  ('political', 'relate'),
#  ('political', 'involved'),
#  ('political', 'governmental'),
#  ('political', 'of'),
#  ('political', 'involve'),
#  ('political', 'to'),
#  ('political', 'charged'),
#  ('political', 'as'),
#  ('political', 'and'),
#  ('political', 'politics'),
#  ('political', 'with'),
#  ('political', 'conduct'),
#  ('political', 'distinguished'),
#  ('political', 'in'),
#  ('political', 'acts'),
#  ('political', 'party'),
#  ('political', 'especially'),
#  ('political', 'administration'),
#  ('political', 'system'),
#  ('political', 'making'),
#  ('political', 'term'),
#  ('political', 'from'),
#  ('defenestration', 'from'),
#  ('from', 'from'),
#  ('from', 'or'),
#  ('from', 'a'),
#  ('from', 'school'),
#  ('from', 'come'),
#  ('from', 'such'),
#  ('from', 'place'),
#  ('from', 'have'),
#  ('from', 'left'),
#  ('from', 'recently'),
#  ('from', 'todaycost'),
#  ('from', 'measure'),
#  ('from', 'separation'),
#  ('from', '3'),
#  ('from', 'activity'),
#  ('from', 'his'),
#  ('from', 'business'),
#  ('from', 'in'),
#  ('from', 'act'),
#  ('from', 'sunrelief'),
#  ('from', 'my'),
#  ('from', 'pay'),
#  ('from', 'point'),
#  ('from', '—'),
#  ('from', 'abstention'),
#  ('from', '1'),
#  ('from', 'differentiation'),
#  ('from', 'home'),
#  ('from', 'word'),
#  ('from', 'exclusion'),
#  ('from', 'start'),
#  ('from', 'her'),
#  ('from', 'indicate'),
#  ('from', 'limits'),
#  ('from', 'source'),
#  ('from', 'necessity'),
#  ('from', 'fatherworke'),
#  ('from', 'call'),
#  ('from', 'basis'),
#  ('from', 'hard'),
#  ('from', 'physical'),
#  ('from', 'to'),
#  ('from', '2'),
#  ('from', 'anxiety'),
#  ('from', 'week'),
#  ('from', 'statement'),
#  ('from', 'function'),
#  ('from', 'focal'),
#  ('from', 'phoneran'),
#  ('from', 'of'),
#  ('from', 'love'),
#  ('from', '$'),
#  ('from', 'removal'),
#  ('from', 'citya'),
#  ('from', 'thisa'),
#  ('from', 'b'),
#  ('from', 'we'),
#  ('from', 'here'),
#  ('from', 'lawyerinherite'),
#  ('from', 'the'),
#  ('from', 'condition'),
#  ('from', 'subtraction'),
#  ('from', 'conclude'),
#  ('from', 'protection'),
#  ('from', 'movement'),
#  ('from', 'agent'),
#  ('from', 'came'),
#  ('from', 'reckoning'),
#  ('from', 'music'),
#  ('from', 'an'),
#  ('from', 'cause'),
#  ('from', 'release'),
#  ('from', 'me'),
#  ('from', 'as'),
#  ('defenestration', 'out'),
#  ('out', 'out'),
#  ('out', 'get'),
#  ('out', 'activity'),
#  ('out', 'occasion'),
#  ('out', 'in'),
#  ('out', 'dress'),
#  ('out', 'or'),
#  ('out', 'special'),
#  ('out', 'particular'),
#  ('out', 'for'),
#  ('out', 'to'),
#  ('out', 'a'),
#  ('out', 'be'),
#  ('out', 'on'),
#  ('out', 'one'),
#  ('out', 'stop'),
#  ('out', 'that'),
#  ('out', 'card'),
#  ('out', 'record'),
#  ('out', 'time'),
#  ('out', 'the'),
#  ('out', 'working'),
#  ('out', 'reading'),
#  ('out', 'is'),
#  ('out', 'down'),
#  ('out', 'word'),
#  ('out', 'hearing'),
#  ('out', 'write'),
#  ('out', 'group'),
#  ('out', 'open'),
#  ('out', 'completion'),
#  ('out', 'as'),
#  ('out', 'unconscious'),
#  ('out', 'share'),
#  ('out', 'other'),
#  ('out', 'full'),
#  ('out', 'point'),
#  ('out', 'shore'),
#  ('out', 'control'),
#  ('out', 'extinction'),
#  ('out', 'insensible'),
#  ('out', 'side'),
#  ('out', 'among'),
#  ('out', 'proper'),
#  ('out', 'baseball'),
#  ('out', 'end'),
#  ('out', 'circulation'),
#  ('out', 'so'),
#  ('out', 'center'),
#  ('out', 'displace'),
#  ('out', 'extent'),
#  ('out', 'depletion'),
#  ('out', 'missing'),
#  ('out', 'usual'),
#  ('out', 'defeat'),
#  ('out', 'turn'),
#  ('out', 'of'),
#  ('out', 'away'),
#  ('out', 'an'),
#  ('out', 'home'),
#  ('out', 'work'),
#  ('out', 'into'),
#  ('out', 'at'),
#  ('out', 'place'),
#  ('out', 'satisfaction'),
#  ('out', 'useless'),
#  ('out', 'player'),
#  ('out', 'vexation'),
#  ('out', 'state'),
#  ('out', 'offensive'),
#  ('out', 'possession'),
#  ('out', 'from'),
#  ('out', 'exhaustion'),
#  ('out', 'inside'),
#  ('out', 'loss'),
#  ('out', 'direction'),
#  ('out', 'loud'),
#  ('out', 'degree'),
#  ('out', 'oneself'),
#  ('out', 'another'),
#  ('out', 'outside'),
#  ('out', 'great'),
#  ('out', 'public'),
#  ('out', 'want'),
#  ('out', 'go'),
#  ('out', 'clothes'),
#  ('defenestration', 'party'),
#  ('party', 'an'),
#  ('party', 'participate'),
#  ('party', 'contest'),
#  ('party', 'of'),
#  ('party', 'in'),
#  ('party', 'a'),
#  ('party', 'affair'),
#  ('party', 'the'),
#  ('party', 'gathering'),
#  ('party', 'government'),
#  ('party', 'person'),
#  ('party', 'take'),
#  ('party', 'question'),
#  ('party', 'provided'),
#  ('party', 'particular'),
#  ('party', 'it'),
#  ('party', 'or'),
#  ('party', 'individual'),
#  ('party', 'policy'),
#  ('party', 'purpose'),
#  ('party', 'group'),
#  ('party', 'entertainment'),
#  ('party', 'action'),
#  ('party', 'direct'),
#  ('party', 'side'),
#  ('party', 'detail'),
#  ('party', 'for'),
#  ('party', 'organized'),
#  ('party', 'soldier'),
#  ('party', 'social'),
#  ('party', 'dispute'),
#  ('party', 'one'),
#  ('defenestration', 'window'),
#  ('window', 'window'),
#  ('window', 'usually'),
#  ('window', 'spectrum'),
#  ('window', 'contain'),
#  ('window', 'successful'),
#  ('window', 'at'),
#  ('window', 'being'),
#  ('window', 'windowpane'),
#  ('window', 'be'),
#  ('window', 'area'),
#  ('window', 'pass'),
#  ('window', 'material'),
#  ('window', 'various'),
#  ('window', 'air'),
#  ('window', 'earth'),
#  ('window', 'atmosphere'),
#  ('window', 'the'),
#  ('window', 'valve'),
#  ('window', 'especially'),
#  ('window', 'resemble'),
#  ('window', 'for'),
#  ('window', 'its'),
#  ('window', 'sensible'),
#  ('window', 'close'),
#  ('window', 'which'),
#  ('window', 'chaff'),
#  ('window', 'casement'),
#  ('window', 'mean'),
#  ('window', 'computer'),
#  ('window', 'open'),
#  ('window', 'obtain'),
#  ('window', 'as'),
#  ('window', 'fitting'),
#  ('window', 'particular'),
#  ('window', 'limits'),
#  ('window', 'and'),
#  ('window', 'such'),
#  ('window', 'spacecraft'),
#  ('window', 'of'),
#  ('window', 'envelope'),
#  ('window', 'output'),
#  ('window', 'screen'),
#  ('window', 'partition'),
#  ('window', 'file'),
#  ('window', 'can'),
#  ('window', 'conduct'),
#  ('window', 'exist'),
#  ('window', 'slot'),
#  ('window', 'space'),
#  ('window', 'on'),
#  ('window', 'certain'),
#  ('window', 'box'),
#  ('window', 'information'),
#  ('window', 'sense'),
#  ('window', 'with'),
#  ('window', 'opening'),
#  ('window', 'glass'),
#  ('window', 'multitasking'),
#  ('window', 'program'),
#  ('window', 'store'),
#  ('window', 'opportunity'),
#  ('window', 'sash'),
#  ('window', 'any'),
#  ('window', 'suggest'),
#  ('window', 'that'),
#  ('window', 'building'),
#  ('window', 'transparent'),
#  ('window', 'time'),
#  ('window', 'through'),
#  ('window', 'appear'),
#  ('window', 'during'),
#  ('window', 'closed'),
#  ('window', 'capable'),
#  ('window', 'shut'),
#  ('window', 'condition'),
#  ('window', 'mission'),
#  ('window', 'an'),
#  ('window', 'wavelength'),
#  ('window', 'behind'),
#  ('window', 'within'),
#  ('window', 'to'),
#  ('window', 'interval'),
#  ('window', 'business'),
#  ('window', 'retail'),
#  ('window', 'is'),
#  ('window', 'shutter'),
#  ('window', 'planet'),
#  ('window', 'rectangular'),
#  ('window', 'panel'),
#  ('window', 'must'),
#  ('window', 'launch'),
#  ('window', 'framework'),
#  ('window', 'entrance'),
#  ('window', 'facilitate'),
#  ('window', 'range'),
#  ('window', 'reentry'),
#  ('window', 'a'),
#  ('window', 'move'),
#  ('window', 'or'),
#  ('window', 'rocket'),
#  ('window', '4'),
#  ('window', 'access'),
#  ('window', 'admission'),
#  ('window', 'light'),
#  ('window', 'accomplish'),
#  ('window', 'by'),
#  ('window', 'electromagnetic'),
#  ('window', 'in'),
#  ('window', 'merchandise'),
#  ('window', 'wall'),
#  ('window', 'resize'),
#  ('window', 'display'),
#  ('defenestration', 'expulsion'),
#  ('expulsion', 'being'),
#  ('expulsion', 'the'),
#  ('expulsion', 'expel'),
#  ('expulsion', 'state'),
#  ('expulsion', 'act'),
#  ('expulsion', 'of'),
#  ('defenestration', 'of'),
#  ('of', 'of'),
#  ('of', 'by'),
#  ('of', 'to'),
#  ('of', 'respect'),
#  ('of', 'relate'),
#  ('of', 'occur'),
#  ('of', 'the'),
#  ('of', 'before'),
#  ('of', 'part'),
#  ('of', 'about'),
#  ('of', 'in'),
#  ('of', 'on'),
#  ('defenestration', 'person'),
#  ('person', 'person'),
#  ('person', 'one'),
#  ('person', 'human'),
#  ('person', 'duty'),
#  ('person', 'or'),
#  ('person', 'corporation'),
#  ('person', 'subject'),
#  ('person', 'verb'),
#  ('person', 'clothing'),
#  ('person', 'mean'),
#  ('person', 'the'),
#  ('person', 'a'),
#  ('person', 'many'),
#  ('person', 'and'),
#  ('person', 'partnership'),
#  ('person', 'nature'),
#  ('person', 'understood'),
#  ('person', 'in'),
#  ('person', 'segment'),
#  ('person', 'unitary'),
#  ('person', 'as'),
#  ('person', 'being'),
#  ('person', 'mode'),
#  ('person', 'discourse'),
#  ('person', 'christ'),
#  ('person', 'indicate'),
#  ('person', 'character'),
#  ('person', 'certain'),
#  ('person', 'of'),
#  ('person', 'trinitarian'),
#  ('person', 'personality'),
#  ('person', 'divine'),
#  ('person', 'speaker'),
#  ('person', 'godhead'),
#  ('person', 'to'),
#  ('person', 'play'),
#  ('person', 'appearance'),
#  ('person', 'right'),
#  ('person', 'body'),
#  ('person', 'that'),
#  ('person', 'by'),
#  ('person', 'spoken'),
#  ('person', 'such'),
#  ('person', 'law'),
#  ('person', 'recognize'),
#  ('person', 'individual'),
#  ('person', 'bodily'),
#  ('person', 'language'),
#  ('person', 'self'),
#  ('person', 'part'),
#  ('person', 'reference'),
#  ('person', 'unite'),
#  ('person', 'inflection'),
#  ('person', 'if'),
#  ('person', 'christians'),
#  ('person', 'is'),
#  ('person', 'pronoun'),
#  ('person', 'guise'),
#  ('person', 'other'),
#  ('person', 'any'),
#  ('person', 'man'),
#  ('person', 'three'),
#  ('defenestration', 'as'),
#  ('as', 'as'),
#  ('as', 'to'),
#  ('as', 'considered'),
#  ('as', 'same'),
#  ('as', 'specify'),
#  ('as', 'such'),
#  ('as', 'amount'),
#  ('as', 'the'),
#  ('as', 'instance'),
#  ('as', 'when'),
#  ('as', 'a'),
#  ('as', 'relation'),
#  ('as', 'form'),
#  ('as', 'or'),
#  ('as', 'in'),
#  ('as', 'degree'),
#  ('as', 'for'),
#  ('defenestration', 'or'),
#  ('or', 'or'),
#  ('or', 'a'),
#  ('or', 'word'),
#  ('or', 'function'),
#  ('or', 'production'),
#  ('or', 'comprehension'),
#  ('or', 'two'),
#  ('or', 'be'),
#  ('or', 'are'),
#  ('or', 'individually'),
#  ('or', 'indicate'),
#  ('or', 'that'),
#  ('or', 'together'),
#  ('or', 'crystal'),
#  ('or', 'language'),
#  ('or', '—'),
#  ('or', 'and'),
#  ('or', 'to'),
#  ('or', 'expression'),
#  ('or', 'as'),
#  ('or', 'whether'),
#  ('or', 'either'),
#  ('or', 'taken'),
#  ('defenestration', 'dismissal'),
#  ('dismissal', 'act'),
#  ('dismissal', 'being'),
#  ('dismissal', 'state'),
#  ('dismissal', 'fact'),
#  ('dismissal', 'or'),
#  ('dismissal', 'the'),
#  ('dismissal', 'dismiss'),
#  ('dismissal', 'of'),
#  ('defenestration', 'a'),
#  ('a', 'a'),
#  ('a', 'especially'),
#  ('a', 'an'),
#  ('a', 'speech'),
#  ('a', 'graphic'),
#  ('a', 'group'),
#  ('a', 'presence'),
#  ('a', 'english'),
#  ('a', 'student'),
#  ('a', 'counterpart'),
#  ('a', 'sixth'),
#  ('a', 'superior'),
#  ('a', 'representation'),
#  ('a', 'designate'),
#  ('a', 'work'),
#  ('a', 'like'),
#  ('a', '1st'),
#  ('a', 'quality'),
#  ('a', 'shape'),
#  ('a', 'first'),
#  ('a', 'tone'),
#  ('a', 'orthographic'),
#  ('a', 'scale'),
#  ('a', 'c'),
#  ('a', 'by'),
#  ('a', 'one'),
#  ('a', 'or'),
#  ('a', 'this'),
#  ('a', 'characterize'),
#  ('a', 'of'),
#  ('a', 'class'),
#  ('a', 'order'),
#  ('a', 'for'),
#  ('a', 'with'),
#  ('a', 'alphabet'),
#  ('a', 'against'),
#  ('a', 'the'),
#  ('a', 'rate'),
#  ('a', 'b'),
#  ('a', 'blood'),
#  ('a', 'grade'),
#  ('a', 'something'),
#  ('a', 'rating'),
#  ('a', 'letter'),
#  ('a', 'in'),
#  ('a', 'present'),
#  ('a', 'and'),
#  ('a', 'reproduce'),
#  ('a', 'antigen'),
#  ('a', 'abo'),
#  ('a', 'antibodie'),
#  ('a', 'four'),
#  ('a', 'device'),
#  ('a', 'doing'),
#  ('a', 'business'),
#  ('a', 'as'),
#  ('defenestration', 'swift'),
#  ('swift', 'respond'),
#  ('swift', 'short'),
#  ('swift', 'great'),
#  ('swift', 'quick'),
#  ('swift', 'or'),
#  ('swift', 'suddenly'),
#  ('swift', 'within'),
#  ('swift', 'speed'),
#  ('swift', 'moving'),
#  ('swift', 'to'),
#  ('swift', 'of'),
#  ('swift', 'very'),
#  ('swift', 'a'),
#  ('swift', 'capable'),
#  ('swift', 'with'),
#  ('swift', 'time'),
#  ('swift', 'ready'),
#  ('swift', 'occur'),
#  ('defenestration', 'throw'),
#  ('throw', 'precipitately'),
#  ('throw', 'particular'),
#  ('throw', 'pitch'),
#  ('throw', 'exert'),
#  ('throw', 'such'),
#  ('throw', 'support'),
#  ('throw', 'commit'),
#  ('throw', 'lose'),
#  ('throw', 'unseat'),
#  ('throw', 'air'),
#  ('throw', 'wheel'),
#  ('throw', 'overcome'),
#  ('throw', 'bear'),
#  ('throw', 'build'),
#  ('throw', 'disconnect'),
#  ('throw', 'carelessly'),
#  ('throw', '3b'),
#  ('throw', 'dash'),
#  ('throw', 'fling'),
#  ('throw', 'violently'),
#  ('throw', 'potter'),
#  ('throw', 'connect'),
#  ('throw', 'forth'),
#  ('throw', 'intentionally'),
#  ('throw', 'automobile'),
#  ('throw', 'the'),
#  ('throw', 'shape'),
#  ('throw', 'motion'),
#  ('throw', 'by'),
#  ('throw', 'off'),
#  ('throw', 'specify'),
#  ('throw', 'clutch'),
#  ('throw', 'perform'),
#  ('throw', 'protection'),
#  ('throw', 'especially'),
#  ('throw', 'condition'),
#  ('throw', 'oneself'),
#  ('throw', 'of'),
#  ('throw', 'two'),
#  ('throw', 'deliver'),
#  ('throw', 'construct'),
#  ('throw', 'propel'),
#  ('throw', 'help'),
#  ('throw', 'a'),
#  ('throw', 'blow'),
#  ('throw', 'on'),
#  ('throw', 'number'),
#  ('throw', 'break'),
#  ('throw', 'make'),
#  ('throw', 'manner'),
#  ('throw', 'shed'),
#  ('throw', 'for'),
#  ('throw', 'twist'),
#  ('throw', 'an'),
#  ('throw', 'roll'),
#  ('throw', 'different'),
#  ('throw', 'into'),
#  ('throw', 'drive'),
#  ('throw', 'arm'),
#  ('throw', 'bring'),
#  ('throw', 'indulge'),
#  ('throw', 'position'),
#  ('throw', 'give'),
#  ('throw', 'fall'),
#  ('throw', 'send'),
#  ('throw', 'part'),
#  ('throw', 'or'),
#  ('throw', 'better'),
#  ('throw', 'way'),
#  ('throw', 'something'),
#  ('throw', 'connection'),
#  ('throw', 'yarn'),
#  ('throw', 'to'),
#  ('throw', '2b'),
#  ('throw', 'cause'),
#  ('throw', 'hand'),
#  ('throw', 'up'),
#  ('throw', 'if'),
#  ('throw', 'successfully'),
#  ('throw', 'as'),
#  ('throw', 'filament'),
#  ('throw', 'get'),
#  ('throw', 'dependent'),
#  ('throw', 'with'),
#  ('throw', 'cast'),
#  ('throw', 'so'),
#  ('throw', '1a'),
#  ('throw', 'put'),
#  ('throw', 'thread'),
#  ('throw', '6b'),
#  ('throw', 'forward'),
#  ('throw', 'impel'),
#  ('throw', 'lever'),
#  ('throw', 'and'),
#  ('throw', 'stunt'),
#  ('throw', 'through'),
#  ('throw', 'gear'),
#  ('throw', 'entertainment'),
#  ('throw', 'project'),
#  ('throw', 'form'),
#  ('throw', 'abandon'),
#  ('throw', 'boxing'),
#  ('throw', 'dice'),
#  ('throw', 'suddenly'),
#  ('throw', 'more'),
#  ('throw', 'deposit'),
#  ('throw', 'hastily'),
#  ('throw', 'quickly'),
#  ('throw', 'any'),
#  ('throw', 'move'),
#  ('throw', 'birth'),
#  ('throw', 'in'),
#  ('throw', 'switch'),
#  ('throw', 'sense')]

# %%
word_path.keys()
# Out:
# dict_keys(['results', 'errors'])

# %%
word_path['results']
# Out:
# [{'columns': ['p'],
#   'data': [{'row': [[{'value': 'defenestration'}, {}, {'value': 'thing'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'fashionable'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756252, 'type': 'relationship', 'deleted': False},
#       {'id': 269534, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '269534',
#        'labels': ['Word'],
#        'properties': {'value': 'fashionable'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756252',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '269534',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'mild'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756236, 'type': 'relationship', 'deleted': False},
#       {'id': 280150, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '280150', 'labels': ['Word'], 'properties': {'value': 'mild'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756236',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '280150',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'dressing'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756256, 'type': 'relationship', 'deleted': False},
#       {'id': 199465, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '199465',
#        'labels': ['Word'],
#        'properties': {'value': 'dressing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756256',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '199465',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'possession'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756204, 'type': 'relationship', 'deleted': False},
#       {'id': 157753, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '157753',
#        'labels': ['Word'],
#        'properties': {'value': 'possession'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756204',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '157753',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'act'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756220, 'type': 'relationship', 'deleted': False},
#       {'id': 89600, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '89600', 'labels': ['Word'], 'properties': {'value': 'act'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756220',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '89600',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'something'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756227, 'type': 'relationship', 'deleted': False},
#       {'id': 259980, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '259980',
#        'labels': ['Word'],
#        'properties': {'value': 'something'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756227',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '259980',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'product'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756222, 'type': 'relationship', 'deleted': False},
#       {'id': 142971, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '142971', 'labels': ['Word'], 'properties': {'value': 'product'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756222',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '142971',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'usually'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756183, 'type': 'relationship', 'deleted': False},
#       {'id': 133703, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '133703', 'labels': ['Word'], 'properties': {'value': 'usually'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756183',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '133703',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'material'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756241, 'type': 'relationship', 'deleted': False},
#       {'id': 175867, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '175867',
#        'labels': ['Word'],
#        'properties': {'value': 'material'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756241',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '175867',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'observation'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756250, 'type': 'relationship', 'deleted': False},
#       {'id': 286034, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '286034',
#        'labels': ['Word'],
#        'properties': {'value': 'observation'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756250',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '286034',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'imply'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756198, 'type': 'relationship', 'deleted': False},
#       {'id': 191998, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '191998', 'labels': ['Word'], 'properties': {'value': 'imply'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756198',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '191998',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'not'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756165, 'type': 'relationship', 'deleted': False},
#       {'id': 256375, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '256375', 'labels': ['Word'], 'properties': {'value': 'not'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756165',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '256375',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'being'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756170, 'type': 'relationship', 'deleted': False},
#       {'id': 217124, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '217124', 'labels': ['Word'], 'properties': {'value': 'being'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756170',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '217124',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'living'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756175, 'type': 'relationship', 'deleted': False},
#       {'id': 282104, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '282104', 'labels': ['Word'], 'properties': {'value': 'living'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756175',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '282104',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'talk'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756255, 'type': 'relationship', 'deleted': False},
#       {'id': 188806, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '188806', 'labels': ['Word'], 'properties': {'value': 'talk'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756255',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '188806',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'appeal'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756232, 'type': 'relationship', 'deleted': False},
#       {'id': 179820, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '179820', 'labels': ['Word'], 'properties': {'value': 'appeal'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756232',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '179820',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'precisely'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756166, 'type': 'relationship', 'deleted': False},
#       {'id': 189773, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '189773',
#        'labels': ['Word'],
#        'properties': {'value': 'precisely'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756166',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '189773',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'situation'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756201, 'type': 'relationship', 'deleted': False},
#       {'id': 198907, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '198907',
#        'labels': ['Word'],
#        'properties': {'value': 'situation'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756201',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '198907',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'proper'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756251, 'type': 'relationship', 'deleted': False},
#       {'id': 127488, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '127488', 'labels': ['Word'], 'properties': {'value': 'proper'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756251',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '127488',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'separate'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756176, 'type': 'relationship', 'deleted': False},
#       {'id': 162803, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '162803',
#        'labels': ['Word'],
#        'properties': {'value': 'separate'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756176',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '162803',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'specialty'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756235, 'type': 'relationship', 'deleted': False},
#       {'id': 220141, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '220141',
#        'labels': ['Word'],
#        'properties': {'value': 'specialty'}}],
#      'relationships': [{'id': '1756235',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '220141',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'general'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756195, 'type': 'relationship', 'deleted': False},
#       {'id': 237380, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '237380', 'labels': ['Word'], 'properties': {'value': 'general'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756195',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '237380',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'from'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756173, 'type': 'relationship', 'deleted': False},
#       {'id': 106257, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '106257', 'labels': ['Word'], 'properties': {'value': 'from'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756173',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '106257',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'article'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756212, 'type': 'relationship', 'deleted': False},
#       {'id': 281733, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '281733', 'labels': ['Word'], 'properties': {'value': 'article'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756212',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '281733',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'to'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756233, 'type': 'relationship', 'deleted': False},
#       {'id': 250166, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '250166', 'labels': ['Word'], 'properties': {'value': 'to'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756233',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '250166',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'write'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756249, 'type': 'relationship', 'deleted': False},
#       {'id': 140347, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '140347', 'labels': ['Word'], 'properties': {'value': 'write'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756249',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '140347',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'designate'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756167, 'type': 'relationship', 'deleted': False},
#       {'id': 245617, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '245617',
#        'labels': ['Word'],
#        'properties': {'value': 'designate'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756167',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '245617',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'accomplishment'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756221, 'type': 'relationship', 'deleted': False},
#       {'id': 243038, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '243038',
#        'labels': ['Word'],
#        'properties': {'value': 'accomplishment'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756221',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '243038',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'activity'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756224, 'type': 'relationship', 'deleted': False},
#       {'id': 233406, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '233406',
#        'labels': ['Word'],
#        'properties': {'value': 'activity'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756224',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '233406',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'of'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756169, 'type': 'relationship', 'deleted': False},
#       {'id': 169684, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '169684', 'labels': ['Word'], 'properties': {'value': 'of'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756169',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '169684',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'an'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756161, 'type': 'relationship', 'deleted': False},
#       {'id': 218665, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '218665', 'labels': ['Word'], 'properties': {'value': 'an'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756161',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '218665',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'distinguished'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756172, 'type': 'relationship', 'deleted': False},
#       {'id': 275707, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '275707',
#        'labels': ['Word'],
#        'properties': {'value': 'distinguished'}}],
#      'relationships': [{'id': '1756172',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '275707',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'concern'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756191, 'type': 'relationship', 'deleted': False},
#       {'id': 246563, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '246563', 'labels': ['Word'], 'properties': {'value': 'concern'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756191',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '246563',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'news'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756246, 'type': 'relationship', 'deleted': False},
#       {'id': 120806, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '120806', 'labels': ['Word'], 'properties': {'value': 'news'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756246',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '120806',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'appearance'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756188, 'type': 'relationship', 'deleted': False},
#       {'id': 250310, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '250310',
#        'labels': ['Word'],
#        'properties': {'value': 'appearance'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756188',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '250310',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'spatial'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756189, 'type': 'relationship', 'deleted': False},
#       {'id': 174445, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '174445',
#        'labels': ['Word'],
#        'properties': {'value': 'spatial'}}],
#      'relationships': [{'id': '1756189',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '174445',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'obsession'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756237, 'type': 'relationship', 'deleted': False},
#       {'id': 234442, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '234442',
#        'labels': ['Word'],
#        'properties': {'value': 'obsession'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756237',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '234442',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'the'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756184, 'type': 'relationship', 'deleted': False},
#       {'id': 114659, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '114659', 'labels': ['Word'], 'properties': {'value': 'the'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756184',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '114659',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'make'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756230, 'type': 'relationship', 'deleted': False},
#       {'id': 221371, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '221371', 'labels': ['Word'], 'properties': {'value': 'make'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756230',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '221371',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'entity'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756164, 'type': 'relationship', 'deleted': False},
#       {'id': 139336, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '139336', 'labels': ['Word'], 'properties': {'value': 'entity'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756164',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '139336',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'own'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756210, 'type': 'relationship', 'deleted': False},
#       {'id': 187943, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '187943', 'labels': ['Word'], 'properties': {'value': 'own'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756210',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '187943',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'concrete'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756185, 'type': 'relationship', 'deleted': False},
#       {'id': 222277, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '222277',
#        'labels': ['Word'],
#        'properties': {'value': 'concrete'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756185',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '222277',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'circumstance'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756203, 'type': 'relationship', 'deleted': False},
#       {'id': 177356, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '177356',
#        'labels': ['Word'],
#        'properties': {'value': 'circumstance'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756203',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '177356',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'utensil'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756215, 'type': 'relationship', 'deleted': False},
#       {'id': 151765, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '151765', 'labels': ['Word'], 'properties': {'value': 'utensil'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756215',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '151765',
#        'properties': {}},
#       {'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'clothing'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756213, 'type': 'relationship', 'deleted': False},
#       {'id': 151748, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '151748',
#        'labels': ['Word'],
#        'properties': {'value': 'clothing'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756213',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '151748',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'spoken'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756248, 'type': 'relationship', 'deleted': False},
#       {'id': 189276, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '189276', 'labels': ['Word'], 'properties': {'value': 'spoken'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781047',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '187219',
#        'properties': {}},
#       {'id': '1756248',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
#        'endNode': '189276',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'thing'},
#       {},
#       {'value': 'as'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781047, 'type': 'relationship', 'deleted': False},
#       {'id': 187219, 'type': 'node', 'deleted': False},
#       {'id': 1756186, 'type': 'relationship', 'deleted': False},
#       {'id': 144993, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '187219',
#        'labels': ['Word'],
#        'properties': {'value': 'thing'}},
#       {'id': '144993', 'labels': ['Word'], 'properties': {'value': 'as'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1756186',
#        'type': 'HAS_WORD',
#        'startNode': '187219',
# ...
#       {},
#       {'value': 'project'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760957, 'type': 'relationship', 'deleted': False},
#       {'id': 286050, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '286050',
#        'labels': ['Word'],
#        'properties': {'value': 'project'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760957',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '286050',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'form'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760937, 'type': 'relationship', 'deleted': False},
#       {'id': 176591, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '257674',
#        'labels': ['Word'],
#        'properties': {'value': 'throw'}},
#       {'id': '176591', 'labels': ['Word'], 'properties': {'value': 'form'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760937',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '176591',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'abandon'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760954, 'type': 'relationship', 'deleted': False},
#       {'id': 164963, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '164963',
#        'labels': ['Word'],
#        'properties': {'value': 'abandon'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760954',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '164963',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'boxing'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760945, 'type': 'relationship', 'deleted': False},
#       {'id': 219202, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '219202',
#        'labels': ['Word'],
#        'properties': {'value': 'boxing'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}},
#       {'id': '1760945',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '219202',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'dice'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760948, 'type': 'relationship', 'deleted': False},
#       {'id': 121978, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '121978',
#        'labels': ['Word'],
#        'properties': {'value': 'dice'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}},
#       {'id': '1760948',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '121978',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'suddenly'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760989, 'type': 'relationship', 'deleted': False},
#       {'id': 191318, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '191318',
#        'labels': ['Word'],
#        'properties': {'value': 'suddenly'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760989',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '191318',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'more'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760994, 'type': 'relationship', 'deleted': False},
#       {'id': 269122, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '269122',
#        'labels': ['Word'],
#        'properties': {'value': 'more'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}},
#       {'id': '1760994',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '269122',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'deposit'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760990, 'type': 'relationship', 'deleted': False},
#       {'id': 194350, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '257674',
#        'labels': ['Word'],
#        'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '194350',
#        'labels': ['Word'],
#        'properties': {'value': 'deposit'}}],
#      'relationships': [{'id': '1760990',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '194350',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'hastily'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760924, 'type': 'relationship', 'deleted': False},
#       {'id': 262280, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '262280',
#        'labels': ['Word'],
#        'properties': {'value': 'hastily'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760924',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '262280',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'quickly'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760988, 'type': 'relationship', 'deleted': False},
#       {'id': 213458, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '213458',
#        'labels': ['Word'],
#        'properties': {'value': 'quickly'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760988',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '213458',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'any'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760899, 'type': 'relationship', 'deleted': False},
#       {'id': 124159, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '257674',
#        'labels': ['Word'],
#        'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}},
#       {'id': '124159', 'labels': ['Word'], 'properties': {'value': 'any'}}],
#      'relationships': [{'id': '1760899',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '124159',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'move'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760972, 'type': 'relationship', 'deleted': False},
#       {'id': 106905, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '106905',
#        'labels': ['Word'],
#        'properties': {'value': 'move'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760972',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '106905',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'birth'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760971, 'type': 'relationship', 'deleted': False},
#       {'id': 137492, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '137492',
#        'labels': ['Word'],
#        'properties': {'value': 'birth'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760971',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '137492',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'in'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760898, 'type': 'relationship', 'deleted': False},
#       {'id': 115321, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '115321',
#        'labels': ['Word'],
#        'properties': {'value': 'in'}},
#       {'id': '257674', 'labels': ['Word'], 'properties': {'value': 'throw'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}},
#       {'id': '1760898',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '115321',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'switch'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760979, 'type': 'relationship', 'deleted': False},
#       {'id': 208318, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '257674',
#        'labels': ['Word'],
#        'properties': {'value': 'throw'}},
#       {'id': '208318', 'labels': ['Word'], 'properties': {'value': 'switch'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '1760979',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '208318',
#        'properties': {}},
#       {'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}}]}},
#    {'row': [[{'value': 'defenestration'},
#       {},
#       {'value': 'throw'},
#       {},
#       {'value': 'sense'}]],
#     'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#       {'id': 781043, 'type': 'relationship', 'deleted': False},
#       {'id': 257674, 'type': 'node', 'deleted': False},
#       {'id': 1760902, 'type': 'relationship', 'deleted': False},
#       {'id': 221759, 'type': 'node', 'deleted': False}]],
#     'graph': {'nodes': [{'id': '257674',
#        'labels': ['Word'],
#        'properties': {'value': 'throw'}},
#       {'id': '221759', 'labels': ['Word'], 'properties': {'value': 'sense'}},
#       {'id': '265787',
#        'labels': ['Word'],
#        'properties': {'value': 'defenestration'}}],
#      'relationships': [{'id': '781043',
#        'type': 'HAS_WORD',
#        'startNode': '265787',
#        'endNode': '257674',
#        'properties': {}},
#       {'id': '1760902',
#        'type': 'HAS_WORD',
#        'startNode': '257674',
#        'endNode': '221759',
#        'properties': {}}]}}]}]

# %%
data_tuples = [(data['row'][0][-3]['value'], data['row'][0][-1]['value']) for data in word_path["results"][0]['data']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_tuples = [(data['row'][0][-3]['value'], data['row'][0][-1]['value']) for data in word_path["results"][0]['data']]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## MsgSpec Practice

# %%
from msgspec.json import decode
from msgspec import Struct

# %%
class Value(Struct):
    word: str
        
class RowItem(Struct):
    value: Value

class Row(Struct):
    row: list[list[dict]]

class Data(Struct):
    data: list[Row]

class Result(Struct):
    results: list[Data]

# %%
def get_word_paths_raw(session, value, path_length):
    # Define the Neo4j query
    query = {
      "statements": [
        {
          "statement": f"MATCH (w:Word) USING TEXT INDEX w:Word(value) WHERE w.value = '{value}' MATCH p = (w)-[:HAS_WORD*1..{path_length}]->(:Word) RETURN p;",
          "resultDataContents": ["row"]
        }
      ]
    }

    # Send the request to the Neo4j endpoint
    response_time = time.time()
    response = session.post(endpoint, json=query, headers=headers)
    print(time.time() - response_time)
    return response.content

def get_word_pairs_raw(session, value, path_length):
    # Define the Neo4j query
    query = {
      "statements": [
        {
          "statement": f"MATCH (w:Word) USING TEXT INDEX w:Word(value) WHERE w.value = '{value}' MATCH (w:Word)-[:HAS_WORD]->(w2:Word) MATCH (w2:Word)-[:HAS_WORD]->(w3:Word) RETURN w.value, w2.value, w3.value;",
          "resultDataContents": ["row"]
        }
      ]
    }

    # Send the request to the Neo4j endpoint
    response_time = time.time()
    response = session.post(endpoint, json=query, headers=headers)
    print(time.time() - response_time)
    return response.json()


def spec_word_rows(spec_response):
    return [(data.row[0][-3]['value'], data.row[0][-1]['value']) for data in spec_response.results[0].data]

# %%
raw_pairs = get_word_pairs_raw(session, "defenestration", 2)
# Out:
# 0.03452944755554199

# %%
raw_pairs
# Out:
# {'results': [{'columns': ['w.value', 'w2.value', 'w3.value'],
#    'data': [{'row': ['defenestration', 'throw', 'sense'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'switch'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'birth'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'move'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'any'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'quickly'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'hastily'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'deposit'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'more'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'suddenly'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'dice'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'boxing'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'abandon'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'form'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'project'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'entertainment'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'gear'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'through'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'stunt'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'lever'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'impel'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'forward'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', '6b'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'thread'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'put'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', '1a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'so'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'cast'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'with'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'dependent'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'get'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'filament'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'successfully'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'if'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'up'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'hand'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'cause'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', '2b'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'yarn'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'connection'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'something'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'way'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'better'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'part'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'send'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'fall'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'give'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'position'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'indulge'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'bring'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'arm'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'drive'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'into'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'different'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'roll'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'twist'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'shed'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'manner'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'make'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'break'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'number'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'on'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'blow'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'help'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'propel'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'construct'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'deliver'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'two'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'oneself'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'condition'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'especially'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'protection'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'perform'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'clutch'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'specify'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'off'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'by'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'motion'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'shape'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'automobile'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'intentionally'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'forth'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'connect'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'potter'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'violently'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'fling'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'dash'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', '3b'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'carelessly'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'disconnect'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'build'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'bear'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'overcome'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'wheel'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'air'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'unseat'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'lose'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'commit'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'support'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'such'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'exert'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'pitch'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'particular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'throw', 'precipitately'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'occur'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'ready'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'time'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'with'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'capable'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'very'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'moving'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'speed'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'within'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'suddenly'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'quick'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'great'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'short'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'swift', 'respond'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'business'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'doing'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'device'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'four'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'antibodie'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'abo'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'antigen'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'reproduce'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'present'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'letter'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'rating'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'something'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'grade'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'blood'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'b'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'rate'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'against'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'alphabet'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'with'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'order'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'class'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'characterize'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'this'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'one'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'by'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'c'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'scale'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'orthographic'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'tone'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'first'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'shape'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'quality'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', '1st'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'like'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'work'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'designate'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'representation'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'superior'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'sixth'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'counterpart'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'student'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'english'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'presence'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'group'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'graphic'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'speech'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'especially'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'a', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'dismiss'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'the'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'fact'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'state'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'being'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'dismissal', 'act'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'taken'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'either'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'whether'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'expression'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', '—'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'language'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'crystal'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'together'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'that'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'indicate'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'individually'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'are'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'be'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'two'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'comprehension'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'production'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'function'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'word'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'or', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'degree'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'form'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'relation'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'when'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'instance'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'amount'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'such'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'specify'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'same'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'considered'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'as', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'three'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'man'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'any'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'other'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'guise'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'pronoun'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'is'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'christians'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'if'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'inflection'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'unite'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'reference'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'part'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'self'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'language'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'bodily'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'individual'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'recognize'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'law'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'such'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'spoken'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'by'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'that'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'body'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'right'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'appearance'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'play'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'godhead'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'speaker'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'divine'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'personality'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'trinitarian'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'certain'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'character'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'indicate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'christ'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'discourse'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'mode'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'being'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'unitary'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'segment'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'understood'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'nature'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'partnership'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'many'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'mean'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'clothing'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'verb'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'subject'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'corporation'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'duty'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'human'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'one'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'person', 'person'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'on'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'about'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'part'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'before'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'occur'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'relate'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'respect'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'by'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'of', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'expulsion', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'expulsion', 'act'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'expulsion', 'state'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'expulsion', 'expel'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'expulsion', 'the'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'expulsion', 'being'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'display'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'resize'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'wall'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'merchandise'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'electromagnetic'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'by'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'accomplish'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'light'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'admission'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'access'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', '4'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'rocket'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'move'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'reentry'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'range'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'facilitate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'entrance'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'framework'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'launch'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'must'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'panel'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'rectangular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'planet'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'shutter'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'is'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'retail'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'business'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'interval'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'within'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'behind'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'wavelength'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'mission'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'condition'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'shut'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'capable'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'closed'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'during'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'appear'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'through'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'time'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'transparent'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'building'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'that'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'suggest'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'any'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'sash'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'opportunity'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'store'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'program'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'multitasking'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'glass'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'opening'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'with'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'sense'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'information'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'box'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'certain'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'on'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'space'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'slot'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'exist'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'conduct'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'can'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'file'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'partition'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'screen'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'output'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'envelope'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'spacecraft'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'such'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'limits'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'particular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'fitting'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'obtain'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'open'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'computer'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'mean'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'casement'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'chaff'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'which'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'close'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'sensible'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'its'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'resemble'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'especially'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'valve'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'atmosphere'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'earth'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'air'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'various'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'material'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'pass'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'area'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'be'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'windowpane'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'being'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'at'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'successful'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'contain'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'spectrum'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'usually'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'window', 'window'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'one'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'dispute'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'social'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'soldier'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'organized'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'detail'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'side'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'direct'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'action'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'entertainment'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'group'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'purpose'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'policy'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'individual'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'it'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'particular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'provided'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'question'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'take'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'person'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'government'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'gathering'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'affair'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'contest'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'participate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'party', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'clothes'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'go'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'want'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'public'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'great'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'outside'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'another'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'oneself'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'degree'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'loud'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'direction'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'loss'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'inside'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'exhaustion'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'from'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'possession'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'offensive'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'state'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'vexation'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'player'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'useless'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'satisfaction'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'place'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'at'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'into'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'work'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'home'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'away'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'turn'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'defeat'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'usual'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'missing'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'depletion'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'extent'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'displace'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'center'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'so'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'circulation'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'end'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'baseball'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'proper'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'among'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'side'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'insensible'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'extinction'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'control'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'shore'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'point'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'full'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'other'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'share'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'unconscious'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'completion'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'open'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'group'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'write'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'hearing'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'word'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'down'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'is'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'reading'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'working'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'time'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'record'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'card'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'that'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'stop'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'one'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'on'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'be'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'particular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'special'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'dress'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'occasion'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'activity'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'get'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'out', 'out'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'me'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'release'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'cause'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'music'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'reckoning'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'came'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'agent'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'movement'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'protection'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'conclude'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'subtraction'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'condition'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'lawyerinherite'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'here'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'we'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'b'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'thisa'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'citya'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'removal'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', '$'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'love'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'phoneran'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'focal'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'function'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'statement'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'week'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'anxiety'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', '2'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'physical'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'hard'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'basis'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'call'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'fatherworke'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'necessity'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'source'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'limits'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'indicate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'her'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'start'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'exclusion'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'word'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'home'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', 'differentiation'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'from', '1'], 'meta': [None, None, None]},
# ...
#     {'row': ['defenestration', 'usually', 'them'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'usually', 'things'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'usually', 'not'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'usually', 'p'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'social'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'must'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'particular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'headquarters'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'person'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'customary'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'transact'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'it'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'whatever'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'authority'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'public'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'attached'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'belong'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'do'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'government'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'which'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'on'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'worship'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'is'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'action'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'apartment'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'exercise'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'another'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'carry'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'subdivision'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'conduct'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'function'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'such'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'professional'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'confer'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'kind'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'enterprise'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'position'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'major'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'rite'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'one'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'perform'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'assign'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'department'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'proper'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'ought'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'business'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'organization'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'something'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'service'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'that'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'religious'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'observance'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'officer'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'governmental'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'unit'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'role'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'purpose'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'some'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'ceremonial'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'supply'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'house'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'done'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'administrative'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'assumed'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'form'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'are'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'prescribe'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'task'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'activity'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'responsibility'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'place'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'receive'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'degree'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'divine'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'by'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'may'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'direct'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'outhouse'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'where'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'executive'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'duty'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'charge'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'special'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'emolument'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'building'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'office', 'office'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'affair'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'may'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'be'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'whatever'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'deed'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'idea'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'effect'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'right'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'fact'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'that'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'such'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'capable'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'especially'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'piece'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'possessed'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'quality'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'specify'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'phobia'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'information'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'distinct'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'aim'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'substance'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'work'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'or'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'for'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'point'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'in'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'within'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'matter'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'its'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'strong'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'individual'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'object'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'event'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'behave'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'purpose'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'and'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'kind'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'forte'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'state'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'inanimate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'sphere'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'particular'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'notion'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'equipment'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'way'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'a'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'effort'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'detail'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'as'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'spoken'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'clothing'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'utensil'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'circumstance'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'concrete'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'own'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'entity'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'make'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'the'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'obsession'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'spatial'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'appearance'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'news'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'concern'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'distinguished'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'an'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'of'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'activity'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'accomplishment'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'designate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'write'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'to'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'article'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'from'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'general'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'specialty'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'separate'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'proper'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'situation'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'precisely'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'appeal'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'talk'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'living'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'being'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'not'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'imply'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'observation'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'material'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'usually'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'product'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'something'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'act'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'possession'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'dressing'],
#      'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'mild'], 'meta': [None, None, None]},
#     {'row': ['defenestration', 'thing', 'fashionable'],
#      'meta': [None, None, None]}]}],
#  'errors': []}

# %%
raw_path = get_word_paths_raw(session, "defenestration", 2)

# %%
type(raw_path)
# Out:
# bytes

# %%
spec_time = time.time()
raw_path = get_word_paths_raw(session, "run", 3)
raw_data = decode(raw_path, type=Result)
rows = spec_word_rows(raw_data)
print(time.time() - spec_time)
# Out:
# 4.4449803829193115
# 7.293426513671875

# %%
# Depth: 1
len(rows)
# Out:
# 17

# %%
# Depth: 2
len(rows)
# Out:
# 890

# %%
# Depth: 3
len(set(rows))
# Out:
# 99756

# %%
# Depth: 4
len(set(rows))
# Out:
# 158100

# %%
json_time = time.time()
json_data = get_word_data(session, "defenestration", 4)
print(time.time() - json_time)
# Out:
# 0.0120086669921875
# 0.016512393951416016
# 0.017012834548950195

# %%
json_data["results"][0]['data'][0]['row'][0][0]
# Out:
# {'value': 'defenestration'}

# %%
raw_data.results[0].data[0].row[0][0]['value']
# Out:
# 'defenestration'

# %%
data_tuples = [(data.row[0][-3]['value'], data.row[0][-1]['value']) for data in raw_data.results[0].data]

# %%
len(data_tuples)
# Out:
# 41586

# %%
raw_data.results[0].data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 set(list(raw_data.results[0].data))
#
# TypeError: unhashable type: 'Row'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 len(set(raw_data.results[0].data))
#
# TypeError: unhashable type: 'Row'

# %%
len(set(rows))
# Out:
# 25182

# %% [markdown]
# ## Putting it together to form Cytoscape Data

# %%
from neo4j_manager import Neo4jHTTPManager

# %%
database = Neo4jHTTPManager()

# %%
data = database.get_word_paths_raw('defenestration', 2)

# %%
json.loads(data)
# Out:
# {'results': [{'columns': ['p'],
#    'data': [{'row': [[{'value': 'defenestration'}, {}, {'value': 'thing'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'fashionable'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756252, 'type': 'relationship', 'deleted': False},
#        {'id': 269534, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'mild'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756236, 'type': 'relationship', 'deleted': False},
#        {'id': 280150, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'dressing'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756256, 'type': 'relationship', 'deleted': False},
#        {'id': 199465, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'possession'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756204, 'type': 'relationship', 'deleted': False},
#        {'id': 157753, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'act'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756220, 'type': 'relationship', 'deleted': False},
#        {'id': 89600, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'something'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756227, 'type': 'relationship', 'deleted': False},
#        {'id': 259980, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'product'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756222, 'type': 'relationship', 'deleted': False},
#        {'id': 142971, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'usually'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756183, 'type': 'relationship', 'deleted': False},
#        {'id': 133703, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'material'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756241, 'type': 'relationship', 'deleted': False},
#        {'id': 175867, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'observation'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756250, 'type': 'relationship', 'deleted': False},
#        {'id': 286034, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'imply'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756198, 'type': 'relationship', 'deleted': False},
#        {'id': 191998, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'not'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756165, 'type': 'relationship', 'deleted': False},
#        {'id': 256375, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'being'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756170, 'type': 'relationship', 'deleted': False},
#        {'id': 217124, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'living'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756175, 'type': 'relationship', 'deleted': False},
#        {'id': 282104, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'talk'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756255, 'type': 'relationship', 'deleted': False},
#        {'id': 188806, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'appeal'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756232, 'type': 'relationship', 'deleted': False},
#        {'id': 179820, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'precisely'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756166, 'type': 'relationship', 'deleted': False},
#        {'id': 189773, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'situation'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756201, 'type': 'relationship', 'deleted': False},
#        {'id': 198907, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'proper'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756251, 'type': 'relationship', 'deleted': False},
#        {'id': 127488, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'separate'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756176, 'type': 'relationship', 'deleted': False},
#        {'id': 162803, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'specialty'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756235, 'type': 'relationship', 'deleted': False},
#        {'id': 220141, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'general'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756195, 'type': 'relationship', 'deleted': False},
#        {'id': 237380, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'from'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756173, 'type': 'relationship', 'deleted': False},
#        {'id': 106257, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'article'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756212, 'type': 'relationship', 'deleted': False},
#        {'id': 281733, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'to'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756233, 'type': 'relationship', 'deleted': False},
#        {'id': 250166, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'write'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756249, 'type': 'relationship', 'deleted': False},
#        {'id': 140347, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'designate'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756167, 'type': 'relationship', 'deleted': False},
#        {'id': 245617, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'accomplishment'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756221, 'type': 'relationship', 'deleted': False},
#        {'id': 243038, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'activity'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756224, 'type': 'relationship', 'deleted': False},
#        {'id': 233406, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'of'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756169, 'type': 'relationship', 'deleted': False},
#        {'id': 169684, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'an'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756161, 'type': 'relationship', 'deleted': False},
#        {'id': 218665, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'distinguished'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756172, 'type': 'relationship', 'deleted': False},
#        {'id': 275707, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'concern'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756191, 'type': 'relationship', 'deleted': False},
#        {'id': 246563, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'news'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756246, 'type': 'relationship', 'deleted': False},
#        {'id': 120806, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'appearance'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756188, 'type': 'relationship', 'deleted': False},
#        {'id': 250310, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'spatial'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756189, 'type': 'relationship', 'deleted': False},
#        {'id': 174445, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'obsession'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756237, 'type': 'relationship', 'deleted': False},
#        {'id': 234442, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'the'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756184, 'type': 'relationship', 'deleted': False},
#        {'id': 114659, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'make'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756230, 'type': 'relationship', 'deleted': False},
#        {'id': 221371, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'entity'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756164, 'type': 'relationship', 'deleted': False},
#        {'id': 139336, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'own'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756210, 'type': 'relationship', 'deleted': False},
#        {'id': 187943, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'concrete'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756185, 'type': 'relationship', 'deleted': False},
#        {'id': 222277, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'circumstance'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756203, 'type': 'relationship', 'deleted': False},
#        {'id': 177356, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'utensil'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756215, 'type': 'relationship', 'deleted': False},
#        {'id': 151765, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'clothing'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756213, 'type': 'relationship', 'deleted': False},
#        {'id': 151748, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'spoken'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756248, 'type': 'relationship', 'deleted': False},
#        {'id': 189276, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'as'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756186, 'type': 'relationship', 'deleted': False},
#        {'id': 144993, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'detail'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756239, 'type': 'relationship', 'deleted': False},
#        {'id': 135199, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'effort'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756226, 'type': 'relationship', 'deleted': False},
#        {'id': 202666, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'a'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756174, 'type': 'relationship', 'deleted': False},
#        {'id': 138219, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'way'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756253, 'type': 'relationship', 'deleted': False},
#        {'id': 115911, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'equipment'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756214, 'type': 'relationship', 'deleted': False},
#        {'id': 267503, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'notion'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756244, 'type': 'relationship', 'deleted': False},
#        {'id': 250073, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'particular'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756200, 'type': 'relationship', 'deleted': False},
#        {'id': 177092, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'sphere'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756199, 'type': 'relationship', 'deleted': False},
#        {'id': 278957, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'inanimate'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756171, 'type': 'relationship', 'deleted': False},
#        {'id': 177004, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'state'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756193, 'type': 'relationship', 'deleted': False},
#        {'id': 157226, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'forte'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756234, 'type': 'relationship', 'deleted': False},
#        {'id': 237479, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'kind'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756243, 'type': 'relationship', 'deleted': False},
#        {'id': 262668, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'and'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756177, 'type': 'relationship', 'deleted': False},
#        {'id': 159566, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'purpose'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756218, 'type': 'relationship', 'deleted': False},
#        {'id': 113932, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'behave'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756254, 'type': 'relationship', 'deleted': False},
#        {'id': 126986, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'event'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756202, 'type': 'relationship', 'deleted': False},
#        {'id': 251146, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'object'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756162, 'type': 'relationship', 'deleted': False},
#        {'id': 264730, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'individual'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756179, 'type': 'relationship', 'deleted': False},
#        {'id': 140283, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'strong'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756231, 'type': 'relationship', 'deleted': False},
#        {'id': 217464, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'its'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756187, 'type': 'relationship', 'deleted': False},
#        {'id': 234769, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'matter'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756190, 'type': 'relationship', 'deleted': False},
#        {'id': 255254, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'within'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756196, 'type': 'relationship', 'deleted': False},
#        {'id': 256956, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'in'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756194, 'type': 'relationship', 'deleted': False},
#        {'id': 115321, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'point'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756240, 'type': 'relationship', 'deleted': False},
#        {'id': 176042, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'for'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756217, 'type': 'relationship', 'deleted': False},
#        {'id': 145128, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'or'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756163, 'type': 'relationship', 'deleted': False},
#        {'id': 139673, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'work'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756223, 'type': 'relationship', 'deleted': False},
#        {'id': 192708, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'substance'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756242, 'type': 'relationship', 'deleted': False},
#        {'id': 232786, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'aim'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756225, 'type': 'relationship', 'deleted': False},
#        {'id': 216643, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'distinct'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756178, 'type': 'relationship', 'deleted': False},
#        {'id': 140840, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'information'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756247, 'type': 'relationship', 'deleted': False},
#        {'id': 248725, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'phobia'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756238, 'type': 'relationship', 'deleted': False},
#        {'id': 143710, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'specify'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756197, 'type': 'relationship', 'deleted': False},
#        {'id': 211096, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'quality'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756180, 'type': 'relationship', 'deleted': False},
#        {'id': 149501, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'possessed'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756209, 'type': 'relationship', 'deleted': False},
#        {'id': 234016, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'piece'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756245, 'type': 'relationship', 'deleted': False},
#        {'id': 140286, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'especially'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756216, 'type': 'relationship', 'deleted': False},
#        {'id': 88475, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'capable'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756168, 'type': 'relationship', 'deleted': False},
#        {'id': 132638, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'such'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756228, 'type': 'relationship', 'deleted': False},
#        {'id': 241384, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'that'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756229, 'type': 'relationship', 'deleted': False},
#        {'id': 152642, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'fact'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756181, 'type': 'relationship', 'deleted': False},
#        {'id': 89024, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'right'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756211, 'type': 'relationship', 'deleted': False},
#        {'id': 87576, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'effect'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756205, 'type': 'relationship', 'deleted': False},
#        {'id': 189038, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'idea'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756182, 'type': 'relationship', 'deleted': False},
#        {'id': 215580, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'deed'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756219, 'type': 'relationship', 'deleted': False},
#        {'id': 237022, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'whatever'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756206, 'type': 'relationship', 'deleted': False},
#        {'id': 148170, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'be'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756208, 'type': 'relationship', 'deleted': False},
#        {'id': 198183, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'may'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756207, 'type': 'relationship', 'deleted': False},
#        {'id': 141604, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'thing'},
#        {},
#        {'value': 'affair'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781047, 'type': 'relationship', 'deleted': False},
#        {'id': 187219, 'type': 'node', 'deleted': False},
#        {'id': 1756192, 'type': 'relationship', 'deleted': False},
#        {'id': 258529, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'}, {}, {'value': 'office'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'office'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306883, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'building'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306929, 'type': 'relationship', 'deleted': False},
#        {'id': 149603, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'emolument'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306870, 'type': 'relationship', 'deleted': False},
#        {'id': 261377, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'special'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306850, 'type': 'relationship', 'deleted': False},
#        {'id': 189190, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'charge'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306852, 'type': 'relationship', 'deleted': False},
#        {'id': 285100, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'duty'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306851, 'type': 'relationship', 'deleted': False},
#        {'id': 126942, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'to'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306866, 'type': 'relationship', 'deleted': False},
#        {'id': 250166, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'executive'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306877, 'type': 'relationship', 'deleted': False},
#        {'id': 105422, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'where'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306906, 'type': 'relationship', 'deleted': False},
#        {'id': 284057, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'outhouse'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306930, 'type': 'relationship', 'deleted': False},
#        {'id': 188615, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'in'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306915, 'type': 'relationship', 'deleted': False},
#        {'id': 115321, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'direct'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306920, 'type': 'relationship', 'deleted': False},
#        {'id': 106277, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'office'},
#        {},
#        {'value': 'may'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781058, 'type': 'relationship', 'deleted': False},
#        {'id': 207396, 'type': 'node', 'deleted': False},
#        {'id': 1306871, 'type': 'relationship', 'deleted': False},
#        {'id': 141604, 'type': 'node', 'deleted': False}]]},
# ...
#        {'value': 'if'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760944, 'type': 'relationship', 'deleted': False},
#        {'id': 269627, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'successfully'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760970, 'type': 'relationship', 'deleted': False},
#        {'id': 187832, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'as'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760943, 'type': 'relationship', 'deleted': False},
#        {'id': 144993, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'filament'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760995, 'type': 'relationship', 'deleted': False},
#        {'id': 178625, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'get'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760908, 'type': 'relationship', 'deleted': False},
#        {'id': 159186, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'dependent'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760960, 'type': 'relationship', 'deleted': False},
#        {'id': 165012, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'with'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760982, 'type': 'relationship', 'deleted': False},
#        {'id': 186564, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'cast'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760947, 'type': 'relationship', 'deleted': False},
#        {'id': 157058, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'so'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760974, 'type': 'relationship', 'deleted': False},
#        {'id': 231022, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': '1a'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760952, 'type': 'relationship', 'deleted': False},
#        {'id': 261847, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'put'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760919, 'type': 'relationship', 'deleted': False},
#        {'id': 110568, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'thread'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760997, 'type': 'relationship', 'deleted': False},
#        {'id': 219481, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': '6b'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760903, 'type': 'relationship', 'deleted': False},
#        {'id': 111291, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'forward'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760892, 'type': 'relationship', 'deleted': False},
#        {'id': 110462, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'impel'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760916, 'type': 'relationship', 'deleted': False},
#        {'id': 232770, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'lever'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760973, 'type': 'relationship', 'deleted': False},
#        {'id': 127270, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'and'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760896, 'type': 'relationship', 'deleted': False},
#        {'id': 159566, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'stunt'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760969, 'type': 'relationship', 'deleted': False},
#        {'id': 163179, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'through'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760887, 'type': 'relationship', 'deleted': False},
#        {'id': 131277, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'gear'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760986, 'type': 'relationship', 'deleted': False},
#        {'id': 174814, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'entertainment'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760933, 'type': 'relationship', 'deleted': False},
#        {'id': 204718, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'project'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760957, 'type': 'relationship', 'deleted': False},
#        {'id': 286050, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'form'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760937, 'type': 'relationship', 'deleted': False},
#        {'id': 176591, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'abandon'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760954, 'type': 'relationship', 'deleted': False},
#        {'id': 164963, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'boxing'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760945, 'type': 'relationship', 'deleted': False},
#        {'id': 219202, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'dice'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760948, 'type': 'relationship', 'deleted': False},
#        {'id': 121978, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'suddenly'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760989, 'type': 'relationship', 'deleted': False},
#        {'id': 191318, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'more'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760994, 'type': 'relationship', 'deleted': False},
#        {'id': 269122, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'deposit'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760990, 'type': 'relationship', 'deleted': False},
#        {'id': 194350, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'hastily'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760924, 'type': 'relationship', 'deleted': False},
#        {'id': 262280, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'quickly'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760988, 'type': 'relationship', 'deleted': False},
#        {'id': 213458, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'any'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760899, 'type': 'relationship', 'deleted': False},
#        {'id': 124159, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'move'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760972, 'type': 'relationship', 'deleted': False},
#        {'id': 106905, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'birth'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760971, 'type': 'relationship', 'deleted': False},
#        {'id': 137492, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'in'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760898, 'type': 'relationship', 'deleted': False},
#        {'id': 115321, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'switch'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760979, 'type': 'relationship', 'deleted': False},
#        {'id': 208318, 'type': 'node', 'deleted': False}]]},
#     {'row': [[{'value': 'defenestration'},
#        {},
#        {'value': 'throw'},
#        {},
#        {'value': 'sense'}]],
#      'meta': [[{'id': 265787, 'type': 'node', 'deleted': False},
#        {'id': 781043, 'type': 'relationship', 'deleted': False},
#        {'id': 257674, 'type': 'node', 'deleted': False},
#        {'id': 1760902, 'type': 'relationship', 'deleted': False},
#        {'id': 221759, 'type': 'node', 'deleted': False}]]}]}],
#  'errors': []}

# %%
decoded_data = decode(data, type=Result)
rows_with_length = database.spec_word_rows_with_length(decoded_data)

# %%
rows_with_length
# Out:
# [('defenestration', 'thing', 2.0),
#  ('thing', 'fashionable', 3.0),
#  ('thing', 'mild', 3.0),
#  ('thing', 'dressing', 3.0),
#  ('thing', 'possession', 3.0),
#  ('thing', 'act', 3.0),
#  ('thing', 'something', 3.0),
#  ('thing', 'product', 3.0),
#  ('thing', 'usually', 3.0),
#  ('thing', 'material', 3.0),
#  ('thing', 'observation', 3.0),
#  ('thing', 'imply', 3.0),
#  ('thing', 'not', 3.0),
#  ('thing', 'being', 3.0),
#  ('thing', 'living', 3.0),
#  ('thing', 'talk', 3.0),
#  ('thing', 'appeal', 3.0),
#  ('thing', 'precisely', 3.0),
#  ('thing', 'situation', 3.0),
#  ('thing', 'proper', 3.0),
#  ('thing', 'separate', 3.0),
#  ('thing', 'specialty', 3.0),
#  ('thing', 'general', 3.0),
#  ('thing', 'from', 3.0),
#  ('thing', 'article', 3.0),
#  ('thing', 'to', 3.0),
#  ('thing', 'write', 3.0),
#  ('thing', 'designate', 3.0),
#  ('thing', 'accomplishment', 3.0),
#  ('thing', 'activity', 3.0),
#  ('thing', 'of', 3.0),
#  ('thing', 'an', 3.0),
#  ('thing', 'distinguished', 3.0),
#  ('thing', 'concern', 3.0),
#  ('thing', 'news', 3.0),
#  ('thing', 'appearance', 3.0),
#  ('thing', 'spatial', 3.0),
#  ('thing', 'obsession', 3.0),
#  ('thing', 'the', 3.0),
#  ('thing', 'make', 3.0),
#  ('thing', 'entity', 3.0),
#  ('thing', 'own', 3.0),
#  ('thing', 'concrete', 3.0),
#  ('thing', 'circumstance', 3.0),
#  ('thing', 'utensil', 3.0),
#  ('thing', 'clothing', 3.0),
#  ('thing', 'spoken', 3.0),
#  ('thing', 'as', 3.0),
#  ('thing', 'detail', 3.0),
#  ('thing', 'effort', 3.0),
#  ('thing', 'a', 3.0),
#  ('thing', 'way', 3.0),
#  ('thing', 'equipment', 3.0),
#  ('thing', 'notion', 3.0),
#  ('thing', 'particular', 3.0),
#  ('thing', 'sphere', 3.0),
#  ('thing', 'inanimate', 3.0),
#  ('thing', 'state', 3.0),
#  ('thing', 'forte', 3.0),
#  ('thing', 'kind', 3.0),
#  ('thing', 'and', 3.0),
#  ('thing', 'purpose', 3.0),
#  ('thing', 'behave', 3.0),
#  ('thing', 'event', 3.0),
#  ('thing', 'object', 3.0),
#  ('thing', 'individual', 3.0),
#  ('thing', 'strong', 3.0),
#  ('thing', 'its', 3.0),
#  ('thing', 'matter', 3.0),
#  ('thing', 'within', 3.0),
#  ('thing', 'in', 3.0),
#  ('thing', 'point', 3.0),
#  ('thing', 'for', 3.0),
#  ('thing', 'or', 3.0),
#  ('thing', 'work', 3.0),
#  ('thing', 'substance', 3.0),
#  ('thing', 'aim', 3.0),
#  ('thing', 'distinct', 3.0),
#  ('thing', 'information', 3.0),
#  ('thing', 'phobia', 3.0),
#  ('thing', 'specify', 3.0),
#  ('thing', 'quality', 3.0),
#  ('thing', 'possessed', 3.0),
#  ('thing', 'piece', 3.0),
#  ('thing', 'especially', 3.0),
#  ('thing', 'capable', 3.0),
#  ('thing', 'such', 3.0),
#  ('thing', 'that', 3.0),
#  ('thing', 'fact', 3.0),
#  ('thing', 'right', 3.0),
#  ('thing', 'effect', 3.0),
#  ('thing', 'idea', 3.0),
#  ('thing', 'deed', 3.0),
#  ('thing', 'whatever', 3.0),
#  ('thing', 'be', 3.0),
#  ('thing', 'may', 3.0),
#  ('thing', 'affair', 3.0),
#  ('defenestration', 'office', 2.0),
#  ('office', 'office', 3.0),
#  ('office', 'building', 3.0),
#  ('office', 'emolument', 3.0),
#  ('office', 'special', 3.0),
#  ('office', 'charge', 3.0),
#  ('office', 'duty', 3.0),
#  ('office', 'to', 3.0),
#  ('office', 'executive', 3.0),
#  ('office', 'where', 3.0),
#  ('office', 'outhouse', 3.0),
#  ('office', 'in', 3.0),
#  ('office', 'direct', 3.0),
#  ('office', 'may', 3.0),
#  ('office', 'by', 3.0),
#  ('office', 'divine', 3.0),
#  ('office', 'degree', 3.0),
#  ('office', 'receive', 3.0),
#  ('office', 'place', 3.0),
#  ('office', 'responsibility', 3.0),
#  ('office', 'activity', 3.0),
#  ('office', 'task', 3.0),
#  ('office', 'prescribe', 3.0),
#  ('office', 'for', 3.0),
#  ('office', 'are', 3.0),
#  ('office', 'form', 3.0),
#  ('office', 'assumed', 3.0),
#  ('office', 'administrative', 3.0),
#  ('office', 'done', 3.0),
#  ('office', 'house', 3.0),
#  ('office', 'the', 3.0),
#  ('office', 'supply', 3.0),
#  ('office', 'ceremonial', 3.0),
#  ('office', 'some', 3.0),
#  ('office', 'purpose', 3.0),
#  ('office', 'role', 3.0),
#  ('office', 'unit', 3.0),
#  ('office', 'governmental', 3.0),
#  ('office', 'officer', 3.0),
#  ('office', 'observance', 3.0),
#  ('office', 'religious', 3.0),
#  ('office', 'that', 3.0),
#  ('office', 'service', 3.0),
#  ('office', 'something', 3.0),
#  ('office', 'organization', 3.0),
#  ('office', 'business', 3.0),
#  ('office', 'ought', 3.0),
#  ('office', 'proper', 3.0),
#  ('office', 'department', 3.0),
#  ('office', 'assign', 3.0),
#  ('office', 'perform', 3.0),
#  ('office', 'one', 3.0),
#  ('office', 'rite', 3.0),
#  ('office', 'an', 3.0),
#  ('office', 'major', 3.0),
#  ('office', 'as', 3.0),
#  ('office', 'position', 3.0),
#  ('office', 'enterprise', 3.0),
#  ('office', 'kind', 3.0),
#  ('office', 'confer', 3.0),
#  ('office', 'professional', 3.0),
#  ('office', 'such', 3.0),
#  ('office', 'or', 3.0),
#  ('office', 'function', 3.0),
#  ('office', 'conduct', 3.0),
#  ('office', 'a', 3.0),
#  ('office', 'subdivision', 3.0),
#  ('office', 'carry', 3.0),
#  ('office', 'another', 3.0),
#  ('office', 'exercise', 3.0),
#  ('office', 'apartment', 3.0),
#  ('office', 'action', 3.0),
#  ('office', 'is', 3.0),
#  ('office', 'worship', 3.0),
#  ('office', 'on', 3.0),
#  ('office', 'which', 3.0),
#  ('office', 'government', 3.0),
#  ('office', 'of', 3.0),
#  ('office', 'do', 3.0),
#  ('office', 'belong', 3.0),
#  ('office', 'attached', 3.0),
#  ('office', 'public', 3.0),
#  ('office', 'authority', 3.0),
#  ('office', 'whatever', 3.0),
#  ('office', 'it', 3.0),
#  ('office', 'and', 3.0),
#  ('office', 'transact', 3.0),
#  ('office', 'customary', 3.0),
#  ('office', 'person', 3.0),
#  ('office', 'headquarters', 3.0),
#  ('office', 'particular', 3.0),
#  ('office', 'must', 3.0),
#  ('office', 'social', 3.0),
#  ('defenestration', 'usually', 2.0),
#  ('usually', 'p', 3.0),
#  ('usually', 'not', 3.0),
#  ('usually', 'things', 3.0),
#  ('usually', 'them', 3.0),
#  ('usually', 'die', 3.0),
#  ('usually', 'away', 3.0),
#  ('usually', 'a', 3.0),
#  ('usually', 'it', 3.0),
#  ('usually', 'does', 3.0),
#  ('usually', 'back', 3.0),
#  ('usually', 'predator', 3.0),
#  ('usually', 'rule', 3.0),
#  ('usually', 'whether', 3.0),
#  ('usually', 'ordinarily', 3.0),
#  ('usually', 'often', 3.0),
#  ('usually', 'customarily', 3.0),
#  ('usually', 'go', 3.0),
#  ('usually', 'as', 3.0),
#  ('usually', 'care', 3.0),
#  ('usually', 'the', 3.0),
#  ('usually', 'most', 3.0),
#  ('usually', 'accord', 3.0),
#  ('usually', 'plant', 3.0),
#  ('usually', 'course', 3.0),
#  ('usually', 'and', 3.0),
#  ('usually', 'mattson', 3.0),
#  ('usually', 'or', 3.0),
#  ('usually', 'to', 3.0),
#  ('usually', 'just', 3.0),
#  ('usually', 'want', 3.0),
#  ('usually', 'usual', 3.0),
#  ('usually', 'come', 3.0),
#  ('usually', 'ordinary', 3.0),
#  ('usually', 'of', 3.0),
#  ('defenestration', 'political', 2.0),
#  ('political', 'political', 3.0),
#  ('political', 'government', 3.0),
#  ('political', 'a', 3.0),
#  ('political', 'or', 3.0),
#  ('political', 'policy', 3.0),
#  ('political', 'concerned', 3.0),
#  ('political', 'the', 3.0),
#  ('political', 'organized', 3.0),
#  ('political', 'against', 3.0),
#  ('political', 'relate', 3.0),
#  ('political', 'involved', 3.0),
#  ('political', 'governmental', 3.0),
#  ('political', 'of', 3.0),
#  ('political', 'involve', 3.0),
#  ('political', 'to', 3.0),
#  ('political', 'charged', 3.0),
#  ('political', 'as', 3.0),
#  ('political', 'and', 3.0),
#  ('political', 'politics', 3.0),
#  ('political', 'with', 3.0),
#  ('political', 'conduct', 3.0),
#  ('political', 'distinguished', 3.0),
#  ('political', 'in', 3.0),
#  ('political', 'acts', 3.0),
#  ('political', 'party', 3.0),
#  ('political', 'especially', 3.0),
#  ('political', 'administration', 3.0),
#  ('political', 'system', 3.0),
#  ('political', 'making', 3.0),
#  ('political', 'term', 3.0),
#  ('political', 'from', 3.0),
#  ('defenestration', 'from', 2.0),
#  ('from', 'from', 3.0),
#  ('from', 'or', 3.0),
#  ('from', 'a', 3.0),
#  ('from', 'school', 3.0),
#  ('from', 'come', 3.0),
#  ('from', 'such', 3.0),
#  ('from', 'place', 3.0),
#  ('from', 'have', 3.0),
#  ('from', 'left', 3.0),
#  ('from', 'recently', 3.0),
#  ('from', 'todaycost', 3.0),
#  ('from', 'measure', 3.0),
#  ('from', 'separation', 3.0),
#  ('from', '3', 3.0),
#  ('from', 'activity', 3.0),
#  ('from', 'his', 3.0),
#  ('from', 'business', 3.0),
#  ('from', 'in', 3.0),
#  ('from', 'act', 3.0),
#  ('from', 'sunrelief', 3.0),
#  ('from', 'my', 3.0),
#  ('from', 'pay', 3.0),
#  ('from', 'point', 3.0),
#  ('from', '—', 3.0),
#  ('from', 'abstention', 3.0),
#  ('from', '1', 3.0),
#  ('from', 'differentiation', 3.0),
#  ('from', 'home', 3.0),
#  ('from', 'word', 3.0),
#  ('from', 'exclusion', 3.0),
#  ('from', 'start', 3.0),
#  ('from', 'her', 3.0),
#  ('from', 'indicate', 3.0),
#  ('from', 'limits', 3.0),
#  ('from', 'source', 3.0),
#  ('from', 'necessity', 3.0),
#  ('from', 'fatherworke', 3.0),
#  ('from', 'call', 3.0),
#  ('from', 'basis', 3.0),
#  ('from', 'hard', 3.0),
#  ('from', 'physical', 3.0),
#  ('from', 'to', 3.0),
#  ('from', '2', 3.0),
#  ('from', 'anxiety', 3.0),
#  ('from', 'week', 3.0),
#  ('from', 'statement', 3.0),
#  ('from', 'function', 3.0),
#  ('from', 'focal', 3.0),
#  ('from', 'phoneran', 3.0),
#  ('from', 'of', 3.0),
#  ('from', 'love', 3.0),
#  ('from', '$', 3.0),
#  ('from', 'removal', 3.0),
#  ('from', 'citya', 3.0),
#  ('from', 'thisa', 3.0),
#  ('from', 'b', 3.0),
#  ('from', 'we', 3.0),
#  ('from', 'here', 3.0),
#  ('from', 'lawyerinherite', 3.0),
#  ('from', 'the', 3.0),
#  ('from', 'condition', 3.0),
#  ('from', 'subtraction', 3.0),
#  ('from', 'conclude', 3.0),
#  ('from', 'protection', 3.0),
#  ('from', 'movement', 3.0),
#  ('from', 'agent', 3.0),
#  ('from', 'came', 3.0),
#  ('from', 'reckoning', 3.0),
#  ('from', 'music', 3.0),
#  ('from', 'an', 3.0),
#  ('from', 'cause', 3.0),
#  ('from', 'release', 3.0),
#  ('from', 'me', 3.0),
#  ('from', 'as', 3.0),
#  ('defenestration', 'out', 2.0),
#  ('out', 'out', 3.0),
#  ('out', 'get', 3.0),
#  ('out', 'activity', 3.0),
#  ('out', 'occasion', 3.0),
#  ('out', 'in', 3.0),
#  ('out', 'dress', 3.0),
#  ('out', 'or', 3.0),
#  ('out', 'special', 3.0),
#  ('out', 'particular', 3.0),
#  ('out', 'for', 3.0),
#  ('out', 'to', 3.0),
#  ('out', 'a', 3.0),
#  ('out', 'be', 3.0),
#  ('out', 'on', 3.0),
#  ('out', 'one', 3.0),
#  ('out', 'stop', 3.0),
#  ('out', 'that', 3.0),
#  ('out', 'card', 3.0),
#  ('out', 'record', 3.0),
#  ('out', 'time', 3.0),
#  ('out', 'the', 3.0),
#  ('out', 'working', 3.0),
#  ('out', 'reading', 3.0),
#  ('out', 'is', 3.0),
#  ('out', 'down', 3.0),
#  ('out', 'word', 3.0),
#  ('out', 'hearing', 3.0),
#  ('out', 'write', 3.0),
#  ('out', 'group', 3.0),
#  ('out', 'open', 3.0),
#  ('out', 'completion', 3.0),
#  ('out', 'as', 3.0),
#  ('out', 'unconscious', 3.0),
#  ('out', 'share', 3.0),
#  ('out', 'other', 3.0),
#  ('out', 'full', 3.0),
#  ('out', 'point', 3.0),
#  ('out', 'shore', 3.0),
#  ('out', 'control', 3.0),
#  ('out', 'extinction', 3.0),
#  ('out', 'insensible', 3.0),
#  ('out', 'side', 3.0),
#  ('out', 'among', 3.0),
#  ('out', 'proper', 3.0),
#  ('out', 'baseball', 3.0),
#  ('out', 'end', 3.0),
#  ('out', 'circulation', 3.0),
#  ('out', 'so', 3.0),
#  ('out', 'center', 3.0),
#  ('out', 'displace', 3.0),
#  ('out', 'extent', 3.0),
#  ('out', 'depletion', 3.0),
#  ('out', 'missing', 3.0),
#  ('out', 'usual', 3.0),
#  ('out', 'defeat', 3.0),
#  ('out', 'turn', 3.0),
#  ('out', 'of', 3.0),
#  ('out', 'away', 3.0),
#  ('out', 'an', 3.0),
#  ('out', 'home', 3.0),
#  ('out', 'work', 3.0),
#  ('out', 'into', 3.0),
#  ('out', 'at', 3.0),
#  ('out', 'place', 3.0),
#  ('out', 'satisfaction', 3.0),
#  ('out', 'useless', 3.0),
#  ('out', 'player', 3.0),
#  ('out', 'vexation', 3.0),
#  ('out', 'state', 3.0),
#  ('out', 'offensive', 3.0),
#  ('out', 'possession', 3.0),
#  ('out', 'from', 3.0),
#  ('out', 'exhaustion', 3.0),
#  ('out', 'inside', 3.0),
#  ('out', 'loss', 3.0),
#  ('out', 'direction', 3.0),
#  ('out', 'loud', 3.0),
#  ('out', 'degree', 3.0),
#  ('out', 'oneself', 3.0),
#  ('out', 'another', 3.0),
#  ('out', 'outside', 3.0),
#  ('out', 'great', 3.0),
#  ('out', 'public', 3.0),
#  ('out', 'want', 3.0),
#  ('out', 'go', 3.0),
#  ('out', 'clothes', 3.0),
#  ('defenestration', 'party', 2.0),
#  ('party', 'an', 3.0),
#  ('party', 'participate', 3.0),
#  ('party', 'contest', 3.0),
#  ('party', 'of', 3.0),
#  ('party', 'in', 3.0),
#  ('party', 'a', 3.0),
#  ('party', 'affair', 3.0),
#  ('party', 'the', 3.0),
#  ('party', 'gathering', 3.0),
#  ('party', 'government', 3.0),
#  ('party', 'person', 3.0),
#  ('party', 'take', 3.0),
#  ('party', 'question', 3.0),
#  ('party', 'provided', 3.0),
#  ('party', 'particular', 3.0),
#  ('party', 'it', 3.0),
#  ('party', 'or', 3.0),
#  ('party', 'individual', 3.0),
#  ('party', 'policy', 3.0),
#  ('party', 'purpose', 3.0),
#  ('party', 'group', 3.0),
#  ('party', 'entertainment', 3.0),
#  ('party', 'action', 3.0),
#  ('party', 'direct', 3.0),
#  ('party', 'side', 3.0),
#  ('party', 'detail', 3.0),
#  ('party', 'for', 3.0),
#  ('party', 'organized', 3.0),
#  ('party', 'soldier', 3.0),
#  ('party', 'social', 3.0),
#  ('party', 'dispute', 3.0),
#  ('party', 'one', 3.0),
#  ('defenestration', 'window', 2.0),
#  ('window', 'window', 3.0),
#  ('window', 'usually', 3.0),
#  ('window', 'spectrum', 3.0),
#  ('window', 'contain', 3.0),
#  ('window', 'successful', 3.0),
#  ('window', 'at', 3.0),
#  ('window', 'being', 3.0),
#  ('window', 'windowpane', 3.0),
#  ('window', 'be', 3.0),
#  ('window', 'area', 3.0),
#  ('window', 'pass', 3.0),
#  ('window', 'material', 3.0),
#  ('window', 'various', 3.0),
#  ('window', 'air', 3.0),
#  ('window', 'earth', 3.0),
#  ('window', 'atmosphere', 3.0),
#  ('window', 'the', 3.0),
#  ('window', 'valve', 3.0),
#  ('window', 'especially', 3.0),
#  ('window', 'resemble', 3.0),
#  ('window', 'for', 3.0),
#  ('window', 'its', 3.0),
#  ('window', 'sensible', 3.0),
#  ('window', 'close', 3.0),
#  ('window', 'which', 3.0),
#  ('window', 'chaff', 3.0),
#  ('window', 'casement', 3.0),
#  ('window', 'mean', 3.0),
#  ('window', 'computer', 3.0),
#  ('window', 'open', 3.0),
#  ('window', 'obtain', 3.0),
#  ('window', 'as', 3.0),
#  ('window', 'fitting', 3.0),
#  ('window', 'particular', 3.0),
#  ('window', 'limits', 3.0),
#  ('window', 'and', 3.0),
#  ('window', 'such', 3.0),
#  ('window', 'spacecraft', 3.0),
#  ('window', 'of', 3.0),
#  ('window', 'envelope', 3.0),
#  ('window', 'output', 3.0),
#  ('window', 'screen', 3.0),
#  ('window', 'partition', 3.0),
#  ('window', 'file', 3.0),
#  ('window', 'can', 3.0),
#  ('window', 'conduct', 3.0),
#  ('window', 'exist', 3.0),
#  ('window', 'slot', 3.0),
#  ('window', 'space', 3.0),
#  ('window', 'on', 3.0),
#  ('window', 'certain', 3.0),
#  ('window', 'box', 3.0),
#  ('window', 'information', 3.0),
#  ('window', 'sense', 3.0),
#  ('window', 'with', 3.0),
#  ('window', 'opening', 3.0),
#  ('window', 'glass', 3.0),
#  ('window', 'multitasking', 3.0),
#  ('window', 'program', 3.0),
#  ('window', 'store', 3.0),
#  ('window', 'opportunity', 3.0),
#  ('window', 'sash', 3.0),
#  ('window', 'any', 3.0),
#  ('window', 'suggest', 3.0),
#  ('window', 'that', 3.0),
#  ('window', 'building', 3.0),
#  ('window', 'transparent', 3.0),
#  ('window', 'time', 3.0),
#  ('window', 'through', 3.0),
#  ('window', 'appear', 3.0),
#  ('window', 'during', 3.0),
#  ('window', 'closed', 3.0),
#  ('window', 'capable', 3.0),
#  ('window', 'shut', 3.0),
#  ('window', 'condition', 3.0),
#  ('window', 'mission', 3.0),
#  ('window', 'an', 3.0),
#  ('window', 'wavelength', 3.0),
#  ('window', 'behind', 3.0),
#  ('window', 'within', 3.0),
#  ('window', 'to', 3.0),
#  ('window', 'interval', 3.0),
#  ('window', 'business', 3.0),
#  ('window', 'retail', 3.0),
#  ('window', 'is', 3.0),
#  ('window', 'shutter', 3.0),
#  ('window', 'planet', 3.0),
#  ('window', 'rectangular', 3.0),
#  ('window', 'panel', 3.0),
#  ('window', 'must', 3.0),
#  ('window', 'launch', 3.0),
#  ('window', 'framework', 3.0),
#  ('window', 'entrance', 3.0),
#  ('window', 'facilitate', 3.0),
#  ('window', 'range', 3.0),
#  ('window', 'reentry', 3.0),
#  ('window', 'a', 3.0),
#  ('window', 'move', 3.0),
#  ('window', 'or', 3.0),
#  ('window', 'rocket', 3.0),
#  ('window', '4', 3.0),
#  ('window', 'access', 3.0),
#  ('window', 'admission', 3.0),
#  ('window', 'light', 3.0),
#  ('window', 'accomplish', 3.0),
#  ('window', 'by', 3.0),
#  ('window', 'electromagnetic', 3.0),
#  ('window', 'in', 3.0),
#  ('window', 'merchandise', 3.0),
#  ('window', 'wall', 3.0),
#  ('window', 'resize', 3.0),
#  ('window', 'display', 3.0),
#  ('defenestration', 'expulsion', 2.0),
#  ('expulsion', 'being', 3.0),
#  ('expulsion', 'the', 3.0),
#  ('expulsion', 'expel', 3.0),
#  ('expulsion', 'state', 3.0),
#  ('expulsion', 'act', 3.0),
#  ('expulsion', 'of', 3.0),
#  ('defenestration', 'of', 2.0),
#  ('of', 'of', 3.0),
#  ('of', 'by', 3.0),
#  ('of', 'to', 3.0),
#  ('of', 'respect', 3.0),
#  ('of', 'relate', 3.0),
#  ('of', 'occur', 3.0),
#  ('of', 'the', 3.0),
#  ('of', 'before', 3.0),
#  ('of', 'part', 3.0),
#  ('of', 'about', 3.0),
#  ('of', 'in', 3.0),
#  ('of', 'on', 3.0),
#  ('defenestration', 'person', 2.0),
#  ('person', 'person', 3.0),
#  ('person', 'one', 3.0),
#  ('person', 'human', 3.0),
#  ('person', 'duty', 3.0),
#  ('person', 'or', 3.0),
#  ('person', 'corporation', 3.0),
#  ('person', 'subject', 3.0),
#  ('person', 'verb', 3.0),
#  ('person', 'clothing', 3.0),
#  ('person', 'mean', 3.0),
#  ('person', 'the', 3.0),
#  ('person', 'a', 3.0),
#  ('person', 'many', 3.0),
#  ('person', 'and', 3.0),
#  ('person', 'partnership', 3.0),
#  ('person', 'nature', 3.0),
#  ('person', 'understood', 3.0),
#  ('person', 'in', 3.0),
#  ('person', 'segment', 3.0),
#  ('person', 'unitary', 3.0),
#  ('person', 'as', 3.0),
#  ('person', 'being', 3.0),
#  ('person', 'mode', 3.0),
#  ('person', 'discourse', 3.0),
#  ('person', 'christ', 3.0),
#  ('person', 'indicate', 3.0),
#  ('person', 'character', 3.0),
#  ('person', 'certain', 3.0),
#  ('person', 'of', 3.0),
#  ('person', 'trinitarian', 3.0),
#  ('person', 'personality', 3.0),
#  ('person', 'divine', 3.0),
#  ('person', 'speaker', 3.0),
#  ('person', 'godhead', 3.0),
#  ('person', 'to', 3.0),
#  ('person', 'play', 3.0),
#  ('person', 'appearance', 3.0),
#  ('person', 'right', 3.0),
#  ('person', 'body', 3.0),
#  ('person', 'that', 3.0),
#  ('person', 'by', 3.0),
#  ('person', 'spoken', 3.0),
#  ('person', 'such', 3.0),
#  ('person', 'law', 3.0),
#  ('person', 'recognize', 3.0),
#  ('person', 'individual', 3.0),
#  ('person', 'bodily', 3.0),
#  ('person', 'language', 3.0),
#  ('person', 'self', 3.0),
#  ('person', 'part', 3.0),
#  ('person', 'reference', 3.0),
#  ('person', 'unite', 3.0),
#  ('person', 'inflection', 3.0),
#  ('person', 'if', 3.0),
#  ('person', 'christians', 3.0),
#  ('person', 'is', 3.0),
#  ('person', 'pronoun', 3.0),
#  ('person', 'guise', 3.0),
#  ('person', 'other', 3.0),
#  ('person', 'any', 3.0),
#  ('person', 'man', 3.0),
#  ('person', 'three', 3.0),
#  ('defenestration', 'as', 2.0),
#  ('as', 'as', 3.0),
#  ('as', 'to', 3.0),
#  ('as', 'considered', 3.0),
#  ('as', 'same', 3.0),
#  ('as', 'specify', 3.0),
#  ('as', 'such', 3.0),
#  ('as', 'amount', 3.0),
#  ('as', 'the', 3.0),
#  ('as', 'instance', 3.0),
#  ('as', 'when', 3.0),
#  ('as', 'a', 3.0),
#  ('as', 'relation', 3.0),
#  ('as', 'form', 3.0),
#  ('as', 'or', 3.0),
#  ('as', 'in', 3.0),
#  ('as', 'degree', 3.0),
#  ('as', 'for', 3.0),
#  ('defenestration', 'or', 2.0),
#  ('or', 'or', 3.0),
#  ('or', 'a', 3.0),
#  ('or', 'word', 3.0),
#  ('or', 'function', 3.0),
#  ('or', 'production', 3.0),
#  ('or', 'comprehension', 3.0),
#  ('or', 'two', 3.0),
#  ('or', 'be', 3.0),
#  ('or', 'are', 3.0),
#  ('or', 'individually', 3.0),
#  ('or', 'indicate', 3.0),
#  ('or', 'that', 3.0),
#  ('or', 'together', 3.0),
#  ('or', 'crystal', 3.0),
#  ('or', 'language', 3.0),
#  ('or', '—', 3.0),
#  ('or', 'and', 3.0),
#  ('or', 'to', 3.0),
#  ('or', 'expression', 3.0),
#  ('or', 'as', 3.0),
#  ('or', 'whether', 3.0),
#  ('or', 'either', 3.0),
#  ('or', 'taken', 3.0),
#  ('defenestration', 'dismissal', 2.0),
#  ('dismissal', 'act', 3.0),
#  ('dismissal', 'being', 3.0),
#  ('dismissal', 'state', 3.0),
#  ('dismissal', 'fact', 3.0),
#  ('dismissal', 'or', 3.0),
#  ('dismissal', 'the', 3.0),
#  ('dismissal', 'dismiss', 3.0),
#  ('dismissal', 'of', 3.0),
#  ('defenestration', 'a', 2.0),
#  ('a', 'a', 3.0),
#  ('a', 'especially', 3.0),
#  ('a', 'an', 3.0),
#  ('a', 'speech', 3.0),
#  ('a', 'graphic', 3.0),
#  ('a', 'group', 3.0),
#  ('a', 'presence', 3.0),
#  ('a', 'english', 3.0),
#  ('a', 'student', 3.0),
#  ('a', 'counterpart', 3.0),
#  ('a', 'sixth', 3.0),
#  ('a', 'superior', 3.0),
#  ('a', 'representation', 3.0),
#  ('a', 'designate', 3.0),
#  ('a', 'work', 3.0),
#  ('a', 'like', 3.0),
#  ('a', '1st', 3.0),
#  ('a', 'quality', 3.0),
#  ('a', 'shape', 3.0),
#  ('a', 'first', 3.0),
#  ('a', 'tone', 3.0),
#  ('a', 'orthographic', 3.0),
#  ('a', 'scale', 3.0),
#  ('a', 'c', 3.0),
#  ('a', 'by', 3.0),
#  ('a', 'one', 3.0),
#  ('a', 'or', 3.0),
#  ('a', 'this', 3.0),
#  ('a', 'characterize', 3.0),
#  ('a', 'of', 3.0),
#  ('a', 'class', 3.0),
#  ('a', 'order', 3.0),
#  ('a', 'for', 3.0),
#  ('a', 'with', 3.0),
#  ('a', 'alphabet', 3.0),
#  ('a', 'against', 3.0),
#  ('a', 'the', 3.0),
#  ('a', 'rate', 3.0),
#  ('a', 'b', 3.0),
#  ('a', 'blood', 3.0),
#  ('a', 'grade', 3.0),
#  ('a', 'something', 3.0),
#  ('a', 'rating', 3.0),
#  ('a', 'letter', 3.0),
#  ('a', 'in', 3.0),
#  ('a', 'present', 3.0),
#  ('a', 'and', 3.0),
#  ('a', 'reproduce', 3.0),
#  ('a', 'antigen', 3.0),
#  ('a', 'abo', 3.0),
#  ('a', 'antibodie', 3.0),
#  ('a', 'four', 3.0),
#  ('a', 'device', 3.0),
#  ('a', 'doing', 3.0),
#  ('a', 'business', 3.0),
#  ('a', 'as', 3.0),
#  ('defenestration', 'swift', 2.0),
#  ('swift', 'respond', 3.0),
#  ('swift', 'short', 3.0),
#  ('swift', 'great', 3.0),
#  ('swift', 'quick', 3.0),
#  ('swift', 'or', 3.0),
#  ('swift', 'suddenly', 3.0),
#  ('swift', 'within', 3.0),
#  ('swift', 'speed', 3.0),
#  ('swift', 'moving', 3.0),
#  ('swift', 'to', 3.0),
#  ('swift', 'of', 3.0),
#  ('swift', 'very', 3.0),
#  ('swift', 'a', 3.0),
#  ('swift', 'capable', 3.0),
#  ('swift', 'with', 3.0),
#  ('swift', 'time', 3.0),
#  ('swift', 'ready', 3.0),
#  ('swift', 'occur', 3.0),
#  ('defenestration', 'throw', 2.0),
#  ('throw', 'precipitately', 3.0),
#  ('throw', 'particular', 3.0),
#  ('throw', 'pitch', 3.0),
#  ('throw', 'exert', 3.0),
#  ('throw', 'such', 3.0),
#  ('throw', 'support', 3.0),
#  ('throw', 'commit', 3.0),
#  ('throw', 'lose', 3.0),
#  ('throw', 'unseat', 3.0),
#  ('throw', 'air', 3.0),
#  ('throw', 'wheel', 3.0),
#  ('throw', 'overcome', 3.0),
#  ('throw', 'bear', 3.0),
#  ('throw', 'build', 3.0),
#  ('throw', 'disconnect', 3.0),
#  ('throw', 'carelessly', 3.0),
#  ('throw', '3b', 3.0),
#  ('throw', 'dash', 3.0),
#  ('throw', 'fling', 3.0),
#  ('throw', 'violently', 3.0),
#  ('throw', 'potter', 3.0),
#  ('throw', 'connect', 3.0),
#  ('throw', 'forth', 3.0),
#  ('throw', 'intentionally', 3.0),
#  ('throw', 'automobile', 3.0),
#  ('throw', 'the', 3.0),
#  ('throw', 'shape', 3.0),
#  ('throw', 'motion', 3.0),
#  ('throw', 'by', 3.0),
#  ('throw', 'off', 3.0),
#  ('throw', 'specify', 3.0),
#  ('throw', 'clutch', 3.0),
#  ('throw', 'perform', 3.0),
#  ('throw', 'protection', 3.0),
#  ('throw', 'especially', 3.0),
#  ('throw', 'condition', 3.0),
#  ('throw', 'oneself', 3.0),
#  ('throw', 'of', 3.0),
#  ('throw', 'two', 3.0),
#  ('throw', 'deliver', 3.0),
#  ('throw', 'construct', 3.0),
#  ('throw', 'propel', 3.0),
#  ('throw', 'help', 3.0),
#  ('throw', 'a', 3.0),
#  ('throw', 'blow', 3.0),
#  ('throw', 'on', 3.0),
#  ('throw', 'number', 3.0),
#  ('throw', 'break', 3.0),
#  ('throw', 'make', 3.0),
#  ('throw', 'manner', 3.0),
#  ('throw', 'shed', 3.0),
#  ('throw', 'for', 3.0),
#  ('throw', 'twist', 3.0),
#  ('throw', 'an', 3.0),
#  ('throw', 'roll', 3.0),
#  ('throw', 'different', 3.0),
#  ('throw', 'into', 3.0),
#  ('throw', 'drive', 3.0),
#  ('throw', 'arm', 3.0),
#  ('throw', 'bring', 3.0),
#  ('throw', 'indulge', 3.0),
#  ('throw', 'position', 3.0),
#  ('throw', 'give', 3.0),
#  ('throw', 'fall', 3.0),
#  ('throw', 'send', 3.0),
#  ('throw', 'part', 3.0),
#  ('throw', 'or', 3.0),
#  ('throw', 'better', 3.0),
#  ('throw', 'way', 3.0),
#  ('throw', 'something', 3.0),
#  ('throw', 'connection', 3.0),
#  ('throw', 'yarn', 3.0),
#  ('throw', 'to', 3.0),
#  ('throw', '2b', 3.0),
#  ('throw', 'cause', 3.0),
#  ('throw', 'hand', 3.0),
#  ('throw', 'up', 3.0),
#  ('throw', 'if', 3.0),
#  ('throw', 'successfully', 3.0),
#  ('throw', 'as', 3.0),
#  ('throw', 'filament', 3.0),
#  ('throw', 'get', 3.0),
#  ('throw', 'dependent', 3.0),
#  ('throw', 'with', 3.0),
#  ('throw', 'cast', 3.0),
#  ('throw', 'so', 3.0),
#  ('throw', '1a', 3.0),
#  ('throw', 'put', 3.0),
#  ('throw', 'thread', 3.0),
#  ('throw', '6b', 3.0),
#  ('throw', 'forward', 3.0),
#  ('throw', 'impel', 3.0),
#  ('throw', 'lever', 3.0),
#  ('throw', 'and', 3.0),
#  ('throw', 'stunt', 3.0),
#  ('throw', 'through', 3.0),
#  ('throw', 'gear', 3.0),
#  ('throw', 'entertainment', 3.0),
#  ('throw', 'project', 3.0),
#  ('throw', 'form', 3.0),
#  ('throw', 'abandon', 3.0),
#  ('throw', 'boxing', 3.0),
#  ('throw', 'dice', 3.0),
#  ('throw', 'suddenly', 3.0),
#  ('throw', 'more', 3.0),
#  ('throw', 'deposit', 3.0),
#  ('throw', 'hastily', 3.0),
#  ('throw', 'quickly', 3.0),
#  ('throw', 'any', 3.0),
#  ('throw', 'move', 3.0),
#  ('throw', 'birth', 3.0),
#  ('throw', 'in', 3.0),
#  ('throw', 'switch', 3.0),
#  ('throw', 'sense', 3.0)]

# %%
dir(database)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'endpoint',
#  'get_word_data',
#  'get_word_paths_raw',
#  'headers',
#  'session',
#  'spec_word_rows']

# %%
initial_value = "defenestration"
word_data = database.get_word_data(initial_value, 1)
# Nodes
nodes = [initial_value]
for word_tuple in word_data:
    nodes.append(word_tuple[1])

cyto_nodes = [
    {
        'data': {'id': word, 'label': word}
    }
    for word in nodes
]

# Edges
cyto_edges = [
    {'data': {'source': source, 'target': target}}
    for source, target in word_data
]

elements = cyto_nodes + cyto_edges

# %%
word_data
# Out:
# [('defenestration', 'thing'),
#  ('defenestration', 'office'),
#  ('defenestration', 'usually'),
#  ('defenestration', 'political'),
#  ('defenestration', 'from'),
#  ('defenestration', 'out'),
#  ('defenestration', 'party'),
#  ('defenestration', 'window'),
#  ('defenestration', 'expulsion'),
#  ('defenestration', 'of'),
#  ('defenestration', 'person'),
#  ('defenestration', 'as'),
#  ('defenestration', 'or'),
#  ('defenestration', 'dismissal'),
#  ('defenestration', 'a'),
#  ('defenestration', 'swift'),
#  ('defenestration', 'throw')]

# %%
print(type(elements))
# Out:
# <class 'list'>

# %%
nodes
# Out:
# ['defenestration',
#  'thing',
#  'fashionable',
#  'mild',
#  'dressing',
#  'possession',
#  'act',
#  'something',
#  'product',
#  'usually',
#  'material',
#  'observation',
#  'imply',
#  'not',
#  'being',
#  'living',
#  'talk',
#  'appeal',
#  'precisely',
#  'situation',
#  'proper',
#  'separate',
#  'specialty',
#  'general',
#  'from',
#  'article',
#  'to',
#  'write',
#  'designate',
#  'accomplishment',
#  'activity',
#  'of',
#  'an',
#  'distinguished',
#  'concern',
#  'news',
#  'appearance',
#  'spatial',
#  'obsession',
#  'the',
#  'make',
#  'entity',
#  'own',
#  'concrete',
#  'circumstance',
#  'utensil',
#  'clothing',
#  'spoken',
#  'as',
#  'detail',
#  'effort',
#  'a',
#  'way',
#  'equipment',
#  'notion',
#  'particular',
#  'sphere',
#  'inanimate',
#  'state',
#  'forte',
#  'kind',
#  'and',
#  'purpose',
#  'behave',
#  'event',
#  'object',
#  'individual',
#  'strong',
#  'its',
#  'matter',
#  'within',
#  'in',
#  'point',
#  'for',
#  'or',
#  'work',
#  'substance',
#  'aim',
#  'distinct',
#  'information',
#  'phobia',
#  'specify',
#  'quality',
#  'possessed',
#  'piece',
#  'especially',
#  'capable',
#  'such',
#  'that',
#  'fact',
#  'right',
#  'effect',
#  'idea',
#  'deed',
#  'whatever',
#  'be',
#  'may',
#  'affair',
#  'office',
#  'office',
#  'building',
#  'emolument',
#  'special',
#  'charge',
#  'duty',
#  'to',
#  'executive',
#  'where',
#  'outhouse',
#  'in',
#  'direct',
#  'may',
#  'by',
#  'divine',
#  'degree',
#  'receive',
#  'place',
#  'responsibility',
#  'activity',
#  'task',
#  'prescribe',
#  'for',
#  'are',
#  'form',
#  'assumed',
#  'administrative',
#  'done',
#  'house',
#  'the',
#  'supply',
#  'ceremonial',
#  'some',
#  'purpose',
#  'role',
#  'unit',
#  'governmental',
#  'officer',
#  'observance',
#  'religious',
#  'that',
#  'service',
#  'something',
#  'organization',
#  'business',
#  'ought',
#  'proper',
#  'department',
#  'assign',
#  'perform',
#  'one',
#  'rite',
#  'an',
#  'major',
#  'as',
#  'position',
#  'enterprise',
#  'kind',
#  'confer',
#  'professional',
#  'such',
#  'or',
#  'function',
#  'conduct',
#  'a',
#  'subdivision',
#  'carry',
#  'another',
#  'exercise',
#  'apartment',
#  'action',
#  'is',
#  'worship',
#  'on',
#  'which',
#  'government',
#  'of',
#  'do',
#  'belong',
#  'attached',
#  'public',
#  'authority',
#  'whatever',
#  'it',
#  'and',
#  'transact',
#  'customary',
#  'person',
#  'headquarters',
#  'particular',
#  'must',
#  'social',
#  'usually',
#  'p',
#  'not',
#  'things',
#  'them',
#  'die',
#  'away',
#  'a',
#  'it',
#  'does',
#  'back',
#  'predator',
#  'rule',
#  'whether',
#  'ordinarily',
#  'often',
#  'customarily',
#  'go',
#  'as',
#  'care',
#  'the',
#  'most',
#  'accord',
#  'plant',
#  'course',
#  'and',
#  'mattson',
#  'or',
#  'to',
#  'just',
#  'want',
#  'usual',
#  'come',
#  'ordinary',
#  'of',
#  'political',
#  'political',
#  'government',
#  'a',
#  'or',
#  'policy',
#  'concerned',
#  'the',
#  'organized',
#  'against',
#  'relate',
#  'involved',
#  'governmental',
#  'of',
#  'involve',
#  'to',
#  'charged',
#  'as',
#  'and',
#  'politics',
#  'with',
#  'conduct',
#  'distinguished',
#  'in',
#  'acts',
#  'party',
#  'especially',
#  'administration',
#  'system',
#  'making',
#  'term',
#  'from',
#  'from',
#  'from',
#  'or',
#  'a',
#  'school',
#  'come',
#  'such',
#  'place',
#  'have',
#  'left',
#  'recently',
#  'todaycost',
#  'measure',
#  'separation',
#  '3',
#  'activity',
#  'his',
#  'business',
#  'in',
#  'act',
#  'sunrelief',
#  'my',
#  'pay',
#  'point',
#  '—',
#  'abstention',
#  '1',
#  'differentiation',
#  'home',
#  'word',
#  'exclusion',
#  'start',
#  'her',
#  'indicate',
#  'limits',
#  'source',
#  'necessity',
#  'fatherworke',
#  'call',
#  'basis',
#  'hard',
#  'physical',
#  'to',
#  '2',
#  'anxiety',
#  'week',
#  'statement',
#  'function',
#  'focal',
#  'phoneran',
#  'of',
#  'love',
#  '$',
#  'removal',
#  'citya',
#  'thisa',
#  'b',
#  'we',
#  'here',
#  'lawyerinherite',
#  'the',
#  'condition',
#  'subtraction',
#  'conclude',
#  'protection',
#  'movement',
#  'agent',
#  'came',
#  'reckoning',
#  'music',
#  'an',
#  'cause',
#  'release',
#  'me',
#  'as',
#  'out',
#  'out',
#  'get',
#  'activity',
#  'occasion',
#  'in',
#  'dress',
#  'or',
#  'special',
#  'particular',
#  'for',
#  'to',
#  'a',
#  'be',
#  'on',
#  'one',
#  'stop',
#  'that',
#  'card',
#  'record',
#  'time',
#  'the',
#  'working',
#  'reading',
#  'is',
#  'down',
#  'word',
#  'hearing',
#  'write',
#  'group',
#  'open',
#  'completion',
#  'as',
#  'unconscious',
#  'share',
#  'other',
#  'full',
#  'point',
#  'shore',
#  'control',
#  'extinction',
#  'insensible',
#  'side',
#  'among',
#  'proper',
#  'baseball',
#  'end',
#  'circulation',
#  'so',
#  'center',
#  'displace',
#  'extent',
#  'depletion',
#  'missing',
#  'usual',
#  'defeat',
#  'turn',
#  'of',
#  'away',
#  'an',
#  'home',
#  'work',
#  'into',
#  'at',
#  'place',
#  'satisfaction',
#  'useless',
#  'player',
#  'vexation',
#  'state',
#  'offensive',
#  'possession',
#  'from',
#  'exhaustion',
#  'inside',
#  'loss',
#  'direction',
#  'loud',
#  'degree',
#  'oneself',
#  'another',
#  'outside',
#  'great',
#  'public',
#  'want',
#  'go',
#  'clothes',
#  'party',
#  'an',
#  'participate',
#  'contest',
#  'of',
#  'in',
#  'a',
#  'affair',
#  'the',
#  'gathering',
#  'government',
#  'person',
#  'take',
#  'question',
#  'provided',
#  'particular',
#  'it',
#  'or',
#  'individual',
#  'policy',
#  'purpose',
#  'group',
#  'entertainment',
#  'action',
#  'direct',
#  'side',
#  'detail',
#  'for',
#  'organized',
#  'soldier',
#  'social',
#  'dispute',
#  'one',
#  'window',
#  'window',
#  'usually',
#  'spectrum',
#  'contain',
#  'successful',
#  'at',
#  'being',
#  'windowpane',
#  'be',
#  'area',
#  'pass',
#  'material',
#  'various',
#  'air',
#  'earth',
#  'atmosphere',
#  'the',
#  'valve',
#  'especially',
#  'resemble',
#  'for',
#  'its',
#  'sensible',
#  'close',
#  'which',
#  'chaff',
#  'casement',
#  'mean',
#  'computer',
#  'open',
#  'obtain',
#  'as',
#  'fitting',
#  'particular',
#  'limits',
#  'and',
#  'such',
#  'spacecraft',
#  'of',
#  'envelope',
#  'output',
#  'screen',
#  'partition',
#  'file',
#  'can',
#  'conduct',
#  'exist',
#  'slot',
#  'space',
#  'on',
#  'certain',
#  'box',
#  'information',
#  'sense',
#  'with',
#  'opening',
#  'glass',
#  'multitasking',
#  'program',
#  'store',
#  'opportunity',
#  'sash',
#  'any',
#  'suggest',
#  'that',
#  'building',
#  'transparent',
#  'time',
#  'through',
#  'appear',
#  'during',
#  'closed',
#  'capable',
#  'shut',
#  'condition',
#  'mission',
#  'an',
#  'wavelength',
#  'behind',
#  'within',
#  'to',
#  'interval',
#  'business',
#  'retail',
#  'is',
#  'shutter',
#  'planet',
#  'rectangular',
#  'panel',
#  'must',
#  'launch',
#  'framework',
#  'entrance',
#  'facilitate',
#  'range',
#  'reentry',
#  'a',
#  'move',
#  'or',
#  'rocket',
#  '4',
#  'access',
#  'admission',
#  'light',
#  'accomplish',
#  'by',
#  'electromagnetic',
#  'in',
#  'merchandise',
#  'wall',
#  'resize',
#  'display',
#  'expulsion',
#  'being',
#  'the',
#  'expel',
#  'state',
#  'act',
#  'of',
#  'of',
#  'of',
#  'by',
#  'to',
#  'respect',
#  'relate',
#  'occur',
#  'the',
#  'before',
#  'part',
#  'about',
#  'in',
#  'on',
#  'person',
#  'person',
#  'one',
#  'human',
#  'duty',
#  'or',
#  'corporation',
#  'subject',
#  'verb',
#  'clothing',
#  'mean',
#  'the',
#  'a',
#  'many',
#  'and',
#  'partnership',
#  'nature',
#  'understood',
#  'in',
#  'segment',
#  'unitary',
#  'as',
#  'being',
#  'mode',
#  'discourse',
#  'christ',
#  'indicate',
#  'character',
#  'certain',
#  'of',
#  'trinitarian',
#  'personality',
#  'divine',
#  'speaker',
#  'godhead',
#  'to',
#  'play',
#  'appearance',
#  'right',
#  'body',
#  'that',
#  'by',
#  'spoken',
#  'such',
#  'law',
#  'recognize',
#  'individual',
#  'bodily',
#  'language',
#  'self',
#  'part',
#  'reference',
#  'unite',
#  'inflection',
#  'if',
#  'christians',
#  'is',
#  'pronoun',
#  'guise',
#  'other',
#  'any',
#  'man',
#  'three',
#  'as',
#  'as',
#  'to',
#  'considered',
#  'same',
#  'specify',
#  'such',
#  'amount',
#  'the',
#  'instance',
#  'when',
#  'a',
#  'relation',
#  'form',
#  'or',
#  'in',
#  'degree',
#  'for',
#  'or',
#  'or',
#  'a',
#  'word',
#  'function',
#  'production',
#  'comprehension',
#  'two',
#  'be',
#  'are',
#  'individually',
#  'indicate',
#  'that',
#  'together',
#  'crystal',
#  'language',
#  '—',
#  'and',
#  'to',
#  'expression',
#  'as',
#  'whether',
#  'either',
#  'taken',
#  'dismissal',
#  'act',
#  'being',
#  'state',
#  'fact',
#  'or',
#  'the',
#  'dismiss',
#  'of',
#  'a',
#  'a',
#  'especially',
#  'an',
#  'speech',
#  'graphic',
#  'group',
#  'presence',
#  'english',
#  'student',
#  'counterpart',
#  'sixth',
#  'superior',
#  'representation',
#  'designate',
#  'work',
#  'like',
#  '1st',
#  'quality',
#  'shape',
#  'first',
#  'tone',
#  'orthographic',
#  'scale',
#  'c',
#  'by',
#  'one',
#  'or',
#  'this',
#  'characterize',
#  'of',
#  'class',
#  'order',
#  'for',
#  'with',
#  'alphabet',
#  'against',
#  'the',
#  'rate',
#  'b',
#  'blood',
#  'grade',
#  'something',
#  'rating',
#  'letter',
#  'in',
#  'present',
#  'and',
#  'reproduce',
#  'antigen',
#  'abo',
#  'antibodie',
#  'four',
#  'device',
#  'doing',
#  'business',
#  'as',
#  'swift',
#  'respond',
#  'short',
#  'great',
#  'quick',
#  'or',
#  'suddenly',
#  'within',
#  'speed',
#  'moving',
#  'to',
#  'of',
#  'very',
#  'a',
#  'capable',
#  'with',
#  'time',
#  'ready',
#  'occur',
#  'throw',
#  'precipitately',
#  'particular',
#  'pitch',
#  'exert',
#  'such',
#  'support',
#  'commit',
#  'lose',
#  'unseat',
#  'air',
#  'wheel',
#  'overcome',
#  'bear',
#  'build',
#  'disconnect',
#  'carelessly',
#  '3b',
#  'dash',
#  'fling',
#  'violently',
#  'potter',
#  'connect',
#  'forth',
#  'intentionally',
#  'automobile',
#  'the',
#  'shape',
#  'motion',
#  'by',
#  'off',
#  'specify',
#  'clutch',
#  'perform',
#  'protection',
#  'especially',
#  'condition',
#  'oneself',
#  'of',
#  'two',
#  'deliver',
#  'construct',
#  'propel',
#  'help',
#  'a',
#  'blow',
#  'on',
#  'number',
#  'break',
#  'make',
#  'manner',
#  'shed',
#  'for',
#  'twist',
#  'an',
#  'roll',
#  'different',
#  'into',
#  'drive',
#  'arm',
#  'bring',
#  'indulge',
#  'position',
#  'give',
#  'fall',
#  'send',
#  'part',
#  'or',
#  'better',
#  'way',
#  'something',
#  'connection',
#  'yarn',
#  'to',
#  '2b',
#  'cause',
#  'hand',
#  'up',
#  'if',
#  'successfully',
#  'as',
#  'filament',
#  'get',
#  'dependent',
#  'with',
#  'cast',
#  'so',
#  '1a',
#  'put',
#  'thread',
#  '6b',
#  'forward',
#  'impel',
#  'lever',
#  'and',
#  'stunt',
#  'through',
#  'gear',
#  'entertainment',
#  'project',
#  'form',
#  'abandon',
#  'boxing',
#  'dice',
#  'suddenly',
#  'more',
#  'deposit',
#  'hastily',
#  'quickly',
#  'any',
#  'move',
#  'birth',
#  'in',
#  'switch',
#  'sense']
